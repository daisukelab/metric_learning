# %%
from utils import *
from fastai.callbacks import SaveModelCallback

VISUALIZE_EMBEDDINGS = True

# %% [markdown]
# ## Prepare Data

# %%
all_data = prepare_CIFAR10_databunch()
toytest = ToyAnomalyDetection(all_data, n_anomaly_labels=1, n_cases=10, distance='euclidean')
# Out:
# Files already downloaded and verified

# %% [markdown]
# ## 1. Conventional softmax model

# %%
# Define model learner
def learner_conventional(train_data):
    learn = cnn_learner(train_data, models.resnet18, metrics=accuracy)
    learn.fit_one_cycle(1)
    learn.unfreeze()
    learn.fit_one_cycle(10, callbacks=[SaveModelCallback(learn)])
    return learn

if VISUALIZE_EMBEDDINGS:
    learn = learner_conventional(all_data)
    visualize_embeddings(learn, 'Simply trained ResNet18 (t-SNE)', all_data)
# Out:
# Total time: 00:13 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.523174</td>
#       <td>1.396082</td>
#       <td>0.502300</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:24 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.032266</td>
#       <td>0.888914</td>
#       <td>0.692900</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.815843</td>
#       <td>0.771285</td>
#       <td>0.737300</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.734107</td>
#       <td>0.657550</td>
#       <td>0.779200</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.632390</td>
#       <td>0.608690</td>
#       <td>0.800000</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.524227</td>
#       <td>0.522632</td>
#       <td>0.826300</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.429881</td>
#       <td>0.475841</td>
#       <td>0.842400</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.352818</td>
#       <td>0.471946</td>
#       <td>0.841500</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.266856</td>
#       <td>0.447670</td>
#       <td>0.857900</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.212649</td>
#       <td>0.447227</td>
#       <td>0.859500</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.188044</td>
#       <td>0.447687</td>
#       <td>0.860100</td>
#       <td>00:14</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 0.8889139890670776.
# Better model found at epoch 1 with val_loss value: 0.7712845206260681.
# Better model found at epoch 2 with val_loss value: 0.657550036907196.
# Better model found at epoch 3 with val_loss value: 0.6086904406547546.
# Better model found at epoch 4 with val_loss value: 0.5226322412490845.
# Better model found at epoch 5 with val_loss value: 0.475841224193573.
# Better model found at epoch 6 with val_loss value: 0.4719463884830475.
# Better model found at epoch 7 with val_loss value: 0.44767022132873535.
# Better model found at epoch 8 with val_loss value: 0.4472266733646393.

# %%
# Test model
toytest.do_tests('Conventional', learner_conventional, delete_models=True)
# Out:
# Testing Conventional for case #0
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.438533</td>
#       <td>1.292184</td>
#       <td>0.526111</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.938464</td>
#       <td>0.801732</td>
#       <td>0.716111</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.726368</td>
#       <td>0.622434</td>
#       <td>0.787778</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.655547</td>
#       <td>0.576288</td>
#       <td>0.800111</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.565882</td>
#       <td>0.645660</td>
#       <td>0.784333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.457784</td>
#       <td>0.506799</td>
#       <td>0.831333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.389668</td>
#       <td>0.444110</td>
#       <td>0.848333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.299577</td>
#       <td>0.430749</td>
#       <td>0.855444</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.215444</td>
#       <td>0.404174</td>
#       <td>0.864222</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.180978</td>
#       <td>0.410220</td>
#       <td>0.868889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.157150</td>
#       <td>0.407059</td>
#       <td>0.870889</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 0.8017318844795227.
# Better model found at epoch 1 with val_loss value: 0.622433602809906.
# Better model found at epoch 2 with val_loss value: 0.5762879252433777.
# Better model found at epoch 4 with val_loss value: 0.5067988634109497.
# Better model found at epoch 5 with val_loss value: 0.44410964846611023.
# Better model found at epoch 6 with val_loss value: 0.4307486116886139.
# Better model found at epoch 7 with val_loss value: 0.40417444705963135.
# Evaluation size => test:(5000, 512), train(22500, 512)
# Better model found at epoch 2 with val_loss value: 0.6593315601348877.
# Better model found at epoch 3 with val_loss value: 0.5978034734725952.
# Better model found at epoch 4 with val_loss value: 0.5145061016082764.
# Better model found at epoch 5 with val_loss value: 0.4961334764957428.
# Better model found at epoch 6 with val_loss value: 0.4663182497024536.
# Better model found at epoch 7 with val_loss value: 0.4440426528453827.
# Evaluation size => test:(5000, 512), train(22500, 512)
# Calculated distances in shape (5000, 22500)
#
# Testing Conventional for case #2
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.416776</td>
#       <td>1.282026</td>
#       <td>0.533778</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.932108</td>
#       <td>0.764154</td>
#       <td>0.734000</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.727013</td>
#       <td>0.599113</td>
#       <td>0.794444</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.642455</td>
#       <td>0.521514</td>
#       <td>0.830333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.540538</td>
#       <td>0.457590</td>
#       <td>0.849000</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.422993</td>
#       <td>0.443564</td>
#       <td>0.855000</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.340213</td>
#       <td>0.397027</td>
#       <td>0.868333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.270037</td>
#       <td>0.370654</td>
#       <td>0.877000</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.188582</td>
#       <td>0.362145</td>
#       <td>0.882889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.151778</td>
#       <td>0.355403</td>
#       <td>0.888444</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.133542</td>
#       <td>0.359406</td>
#       <td>0.887778</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 0.7641544342041016.
# Better model found at epoch 1 with val_loss value: 0.5991129279136658.
# Better model found at epoch 2 with val_loss value: 0.5215135812759399.
# Better model found at epoch 3 with val_loss value: 0.4575899541378021.
# Better model found at epoch 4 with val_loss value: 0.4435638189315796.
# Better model found at epoch 5 with val_loss value: 0.3970268964767456.
# Better model found at epoch 6 with val_loss value: 0.3706536591053009.
# Better model found at epoch 7 with val_loss value: 0.3621446490287781.
# Better model found at epoch 8 with val_loss value: 0.35540303587913513.
# Evaluation size => test:(5000, 512), train(22500, 512)
# Calculated distances in shape (5000, 22500)
#
# Testing Conventional for case #3
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.432308</td>
#       <td>1.308969</td>
#       <td>0.514333</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.935092</td>
#       <td>0.805994</td>
#       <td>0.714556</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.782494</td>
#       <td>0.661616</td>
#       <td>0.768111</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.688251</td>
#       <td>0.580631</td>
#       <td>0.806667</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.559080</td>
#       <td>0.522836</td>
#       <td>0.820444</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.483977</td>
#       <td>0.459469</td>
#       <td>0.840222</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.407793</td>
#       <td>0.456515</td>
#       <td>0.843333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.298369</td>
#       <td>0.407620</td>
#       <td>0.857778</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.210222</td>
#       <td>0.415734</td>
#       <td>0.864111</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.184226</td>
#       <td>0.408742</td>
#       <td>0.870444</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.165418</td>
#       <td>0.413491</td>
#       <td>0.870556</td>
#       <td>00:12</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 0.80599445104599.
# Better model found at epoch 1 with val_loss value: 0.6616160273551941.
# Better model found at epoch 2 with val_loss value: 0.5806306600570679.
# Better model found at epoch 3 with val_loss value: 0.5228361487388611.
# Better model found at epoch 4 with val_loss value: 0.45946913957595825.
# Better model found at epoch 5 with val_loss value: 0.45651474595069885.
# Better model found at epoch 6 with val_loss value: 0.40761980414390564.
# Evaluation size => test:(5000, 512), train(22500, 512)
# Calculated distances in shape (5000, 22500)
#
# Testing Conventional for case #4
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.444758</td>
#       <td>1.315088</td>
#       <td>0.526667</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.949239</td>
#       <td>0.823015</td>
#       <td>0.709444</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.720122</td>
#       <td>0.711784</td>
#       <td>0.767444</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.662404</td>
#       <td>0.625895</td>
#       <td>0.783222</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.558418</td>
#       <td>0.520648</td>
#       <td>0.826889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.450274</td>
#       <td>0.434366</td>
#       <td>0.856000</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.358034</td>
#       <td>0.441706</td>
#       <td>0.859556</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.260507</td>
#       <td>0.406236</td>
#       <td>0.871333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.212702</td>
#       <td>0.386560</td>
#       <td>0.880556</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.159264</td>
#       <td>0.378919</td>
#       <td>0.883778</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.139479</td>
#       <td>0.384759</td>
#       <td>0.884111</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 0.8230147361755371.
# Better model found at epoch 1 with val_loss value: 0.7117836475372314.
# Better model found at epoch 2 with val_loss value: 0.6258947253227234.
# Better model found at epoch 3 with val_loss value: 0.5206477642059326.
# Better model found at epoch 4 with val_loss value: 0.4343656897544861.
# Better model found at epoch 6 with val_loss value: 0.40623602271080017.
# Better model found at epoch 7 with val_loss value: 0.3865595757961273.
# Better model found at epoch 8 with val_loss value: 0.37891918420791626.
# Evaluation size => test:(5000, 512), train(22500, 512)
# Calculated distances in shape (5000, 22500)
#
# Testing Conventional for case #5
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.484789</td>
#       <td>1.360786</td>
#       <td>0.507333</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.010837</td>
#       <td>0.845848</td>
#       <td>0.699778</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.804100</td>
#       <td>0.652107</td>
#       <td>0.771778</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.724027</td>
#       <td>0.663533</td>
#       <td>0.777222</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.618858</td>
#       <td>0.584287</td>
#       <td>0.805222</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.491698</td>
#       <td>0.537245</td>
#       <td>0.818111</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.419905</td>
#       <td>0.456797</td>
#       <td>0.844222</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.325394</td>
#       <td>0.440001</td>
#       <td>0.852222</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.254141</td>
#       <td>0.436559</td>
#       <td>0.857889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.199411</td>
#       <td>0.439995</td>
#       <td>0.862444</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.182442</td>
#       <td>0.437533</td>
#       <td>0.862778</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 0.8458483815193176.
# Better model found at epoch 1 with val_loss value: 0.652106761932373.
# Better model found at epoch 3 with val_loss value: 0.5842873454093933.
# Better model found at epoch 4 with val_loss value: 0.5372446775436401.
# Better model found at epoch 5 with val_loss value: 0.45679736137390137.
# Better model found at epoch 6 with val_loss value: 0.44000110030174255.
# Better model found at epoch 7 with val_loss value: 0.4365590810775757.
# Evaluation size => test:(5000, 512), train(22500, 512)
# Calculated distances in shape (5000, 22500)
#
# Testing Conventional for case #6
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.462451</td>
#       <td>1.347493</td>
#       <td>0.506000</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.997676</td>
#       <td>0.863724</td>
#       <td>0.692444</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.771412</td>
#       <td>0.689245</td>
#       <td>0.767444</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.713728</td>
#       <td>0.588998</td>
#       <td>0.807000</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.602062</td>
#       <td>0.557646</td>
#       <td>0.812222</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.513434</td>
#       <td>0.518677</td>
#       <td>0.824111</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.416874</td>
#       <td>0.497211</td>
#       <td>0.829667</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.325331</td>
#       <td>0.469268</td>
#       <td>0.844556</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.238430</td>
#       <td>0.451330</td>
#       <td>0.857778</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.203634</td>
#       <td>0.459290</td>
#       <td>0.856556</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.163668</td>
#       <td>0.451558</td>
#       <td>0.860000</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 0.8637238144874573.
# Better model found at epoch 1 with val_loss value: 0.689245343208313.
# Better model found at epoch 2 with val_loss value: 0.5889977216720581.
# Better model found at epoch 3 with val_loss value: 0.557645857334137.
# Better model found at epoch 4 with val_loss value: 0.5186774730682373.
# Better model found at epoch 5 with val_loss value: 0.4972109794616699.
# Better model found at epoch 6 with val_loss value: 0.46926823258399963.
# Better model found at epoch 7 with val_loss value: 0.4513295292854309.
# Evaluation size => test:(5000, 512), train(22500, 512)
# Calculated distances in shape (5000, 22500)
#
# Testing Conventional for case #7
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.467667</td>
#       <td>1.353662</td>
#       <td>0.514222</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:12 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.976334</td>
#       <td>0.877192</td>
#       <td>0.688444</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.806886</td>
#       <td>0.698478</td>
#       <td>0.757333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.669907</td>
#       <td>0.676133</td>
#       <td>0.775000</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.591332</td>
#       <td>0.586047</td>
#       <td>0.801556</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.492413</td>
#       <td>0.551850</td>
#       <td>0.812667</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.404902</td>
#       <td>0.485702</td>
#       <td>0.835333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.314054</td>
#       <td>0.452590</td>
#       <td>0.849889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.239325</td>
#       <td>0.449065</td>
#       <td>0.852778</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.195960</td>
#       <td>0.447017</td>
#       <td>0.860000</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.160768</td>
#       <td>0.453428</td>
#       <td>0.860333</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 0.8771921992301941.
# Better model found at epoch 1 with val_loss value: 0.6984779834747314.
# Better model found at epoch 2 with val_loss value: 0.6761333346366882.
# Better model found at epoch 3 with val_loss value: 0.5860471725463867.
# Better model found at epoch 4 with val_loss value: 0.5518497228622437.
# Better model found at epoch 5 with val_loss value: 0.48570165038108826.
# Better model found at epoch 6 with val_loss value: 0.45259007811546326.
# Better model found at epoch 7 with val_loss value: 0.44906532764434814.
# Better model found at epoch 8 with val_loss value: 0.44701698422431946.
# Evaluation size => test:(5000, 512), train(22500, 512)
# Calculated distances in shape (5000, 22500)
#
# Testing Conventional for case #8
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.486279</td>
#       <td>1.364287</td>
#       <td>0.510667</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:12 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.025720</td>
#       <td>0.877639</td>
#       <td>0.687222</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.814036</td>
#       <td>0.695960</td>
#       <td>0.762556</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.739158</td>
#       <td>0.630194</td>
#       <td>0.791111</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.623866</td>
#       <td>0.611653</td>
#       <td>0.796778</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.503513</td>
#       <td>0.576632</td>
#       <td>0.806000</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.439903</td>
#       <td>0.481153</td>
#       <td>0.836889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.332032</td>
#       <td>0.474276</td>
#       <td>0.841444</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.256205</td>
#       <td>0.446907</td>
#       <td>0.850667</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.193909</td>
#       <td>0.454003</td>
#       <td>0.855000</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.193420</td>
#       <td>0.453725</td>
#       <td>0.856333</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 0.87763911485672.
# Better model found at epoch 1 with val_loss value: 0.6959604024887085.
# Better model found at epoch 2 with val_loss value: 0.6301937103271484.
# Better model found at epoch 3 with val_loss value: 0.6116527318954468.
# Better model found at epoch 4 with val_loss value: 0.5766317248344421.
# Better model found at epoch 5 with val_loss value: 0.481153279542923.
# Better model found at epoch 6 with val_loss value: 0.47427570819854736.
# Better model found at epoch 7 with val_loss value: 0.44690659642219543.
# Evaluation size => test:(5000, 512), train(22500, 512)
# Calculated distances in shape (5000, 22500)
#
# Testing Conventional for case #9
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.463370</td>
#       <td>1.330000</td>
#       <td>0.525222</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:12 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.991438</td>
#       <td>0.858085</td>
#       <td>0.696444</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.802076</td>
#       <td>0.744058</td>
#       <td>0.748556</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.707719</td>
#       <td>0.623914</td>
#       <td>0.792333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.592916</td>
#       <td>0.655743</td>
#       <td>0.778778</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.529895</td>
#       <td>0.521255</td>
#       <td>0.827667</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.418659</td>
#       <td>0.497104</td>
#       <td>0.831556</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.317877</td>
#       <td>0.454249</td>
#       <td>0.851444</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.252334</td>
#       <td>0.476515</td>
#       <td>0.851889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.199951</td>
#       <td>0.451516</td>
#       <td>0.862778</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.171298</td>
#       <td>0.450125</td>
#       <td>0.864222</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 0.8580846190452576.
# Better model found at epoch 1 with val_loss value: 0.7440581917762756.
# Better model found at epoch 2 with val_loss value: 0.6239137649536133.
# Better model found at epoch 4 with val_loss value: 0.5212545394897461.
# Better model found at epoch 5 with val_loss value: 0.49710437655448914.
# Better model found at epoch 6 with val_loss value: 0.4542487859725952.
# Better model found at epoch 8 with val_loss value: 0.4515160322189331.
# Better model found at epoch 9 with val_loss value: 0.4501250088214874.
# Evaluation size => test:(5000, 512), train(22500, 512)
# Calculated distances in shape (5000, 22500)
# Deleting *.pth under /home/blmdr/lab/metric_learning/data_CIFAR10/images...

# %%
distance_df, (auc, fpr, tpr), worst_test_info = toytest.results['Conventional'][0]
worst_test_info
# Out:
#                          x     y  distance  train_idx                train_x  \
# 3488  bird/img2_008252.png  bird  0.355092      18381    cat/img3_049466.png
# 3037  bird/img2_009825.png  bird  0.484806       9725   deer/img4_047385.png
# 3169  bird/img2_003094.png  bird  0.510454      20451  plane/img0_035446.png
# 3140  bird/img2_002303.png  bird  0.522930       5127    dog/img5_001991.png
# 3241  bird/img2_001451.png  bird  0.529838      17981    cat/img3_014919.png
#
#      train_y
# 3488     cat
# 3037    deer
# 3169   plane
# 3140     dog
# 3241     cat

# %%
toytest.show_worst_test_images('Conventional', worst_test_info, 0)

# %% [markdown]
# ## 2. L2-constrained Softmax Loss
#
# - R. Ranjan, C. D. Castillo, and R. Chellappa. L2-constrained softmax loss for discriminative face verification. arXiv preprint arXiv:1703.09507, 2017. https://arxiv.org/pdf/1703.09507.pdf

# %%
# Define model learner
class L2ConstraintedNet(nn.Module):
    def __init__(self, org_model, alpha=16, num_classes=1000):
        super().__init__()
        self.org_model = org_model
        self.alpha = alpha

    def forward(self, x):
        x = self.org_model(x)
        
        l2 = torch.sqrt((x**2).sum())
        x = self.alpha * (x / l2)
        return x

def learner_L2ConstraintedNet(train_data):
    learn = cnn_learner(train_data, models.resnet18, metrics=accuracy)
    learn.model = L2ConstraintedNet(learn.model)
    learn.fit_one_cycle(1)
    learn.unfreeze()
    learn.fit_one_cycle(10, callbacks=[SaveModelCallback(learn)])
    return learn

if VISUALIZE_EMBEDDINGS:
    visualize_embeddings(learner_L2ConstraintedNet(all_data), 'L2 constrainted ResNet18 (t-SNE)', all_data)
# Out:
# Total time: 00:12 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.664499</td>
#       <td>1.604064</td>
#       <td>0.506400</td>
#       <td>00:12</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:28 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.310926</td>
#       <td>1.257597</td>
#       <td>0.699300</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.188874</td>
#       <td>1.128459</td>
#       <td>0.772400</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.146633</td>
#       <td>1.124626</td>
#       <td>0.777100</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.080084</td>
#       <td>1.064174</td>
#       <td>0.805700</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.040518</td>
#       <td>1.030163</td>
#       <td>0.824600</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.003317</td>
#       <td>1.012847</td>
#       <td>0.837600</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.953611</td>
#       <td>0.991137</td>
#       <td>0.847700</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.912977</td>
#       <td>0.983027</td>
#       <td>0.853800</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.886296</td>
#       <td>0.972129</td>
#       <td>0.860400</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.877582</td>
#       <td>0.974725</td>
#       <td>0.859400</td>
#       <td>00:14</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 1.2575972080230713.
# Better model found at epoch 1 with val_loss value: 1.1284592151641846.
# Better model found at epoch 2 with val_loss value: 1.124625563621521.
# Better model found at epoch 3 with val_loss value: 1.0641735792160034.
# Better model found at epoch 4 with val_loss value: 1.0301626920700073.
# Better model found at epoch 5 with val_loss value: 1.0128474235534668.
# Better model found at epoch 6 with val_loss value: 0.991136908531189.
# Better model found at epoch 7 with val_loss value: 0.9830270409584045.
# Better model found at epoch 8 with val_loss value: 0.9721294641494751.

# %%
toytest.do_tests('L2-constrainted', learner_L2ConstraintedNet, delete_models=True)
# Out:
# Testing L2-constrainted for case #0
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.544784</td>
#       <td>1.500165</td>
#       <td>0.533556</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:20 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.207939</td>
#       <td>1.126266</td>
#       <td>0.739222</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.090026</td>
#       <td>1.028753</td>
#       <td>0.788667</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.046294</td>
#       <td>1.021554</td>
#       <td>0.795778</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.000057</td>
#       <td>0.973931</td>
#       <td>0.819222</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.947420</td>
#       <td>0.939932</td>
#       <td>0.841111</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.911998</td>
#       <td>0.920736</td>
#       <td>0.852333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.871760</td>
#       <td>0.905652</td>
#       <td>0.857889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.823071</td>
#       <td>0.890405</td>
#       <td>0.868778</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.804296</td>
#       <td>0.885315</td>
#       <td>0.873556</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.793301</td>
#       <td>0.882762</td>
#       <td>0.874000</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 1.126266360282898.
# Better model found at epoch 1 with val_loss value: 1.0287529230117798.
# Better model found at epoch 2 with val_loss value: 1.0215544700622559.
# Better model found at epoch 3 with val_loss value: 0.9739313125610352.
# Better model found at epoch 4 with val_loss value: 0.9399321675300598.
# Better model found at epoch 5 with val_loss value: 0.9207364320755005.
# Better model found at epoch 6 with val_loss value: 0.9056524634361267.
# Better model found at epoch 7 with val_loss value: 0.890404999256134.
# Better model found at epoch 8 with val_loss value: 0.8853145837783813.
# Better model found at epoch 9 with val_loss value: 0.8827624917030334.
# Evaluation size => test:(5000, 512), train(22500, 512)
# Calculated distances in shape (5000, 22500)
#
# Testing L2-constrainted for case #1
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.588322</td>
#       <td>1.519854</td>
#       <td>0.521778</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:13 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.246587</td>
#       <td>1.173563</td>
#       <td>0.710444</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.128010</td>
#       <td>1.089086</td>
#       <td>0.756667</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.075343</td>
#       <td>1.085018</td>
#       <td>0.763556</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.023838</td>
#       <td>1.007140</td>
#       <td>0.801333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.977948</td>
#       <td>0.991183</td>
#       <td>0.811333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.934608</td>
#       <td>0.938197</td>
#       <td>0.841111</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.882696</td>
#       <td>0.924763</td>
#       <td>0.849556</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.836461</td>
#       <td>0.912618</td>
#       <td>0.855333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.813962</td>
#       <td>0.909790</td>
#       <td>0.858889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.801227</td>
#       <td>0.911908</td>
#       <td>0.860000</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 1.1735628843307495.
# Better model found at epoch 1 with val_loss value: 1.0890864133834839.
# Better model found at epoch 2 with val_loss value: 1.0850178003311157.
# Better model found at epoch 3 with val_loss value: 1.007139801979065.
# Better model found at epoch 4 with val_loss value: 0.9911829233169556.
# Better model found at epoch 5 with val_loss value: 0.9381974935531616.
# Better model found at epoch 6 with val_loss value: 0.9247633218765259.
# Better model found at epoch 7 with val_loss value: 0.9126176238059998.
# Better model found at epoch 8 with val_loss value: 0.9097896814346313.
# Evaluation size => test:(5000, 512), train(22500, 512)
# Calculated distances in shape (5000, 22500)
#
# Testing L2-constrainted for case #2
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.557232</td>
#       <td>1.496612</td>
#       <td>0.534111</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:13 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.194568</td>
#       <td>1.109874</td>
#       <td>0.747556</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.054726</td>
#       <td>1.019021</td>
#       <td>0.796778</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.008981</td>
#       <td>0.974809</td>
#       <td>0.821111</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.962969</td>
#       <td>0.924416</td>
#       <td>0.851111</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.921837</td>
#       <td>0.915352</td>
#       <td>0.854444</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.885391</td>
#       <td>0.894346</td>
#       <td>0.864667</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.838524</td>
#       <td>0.873156</td>
#       <td>0.876889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.821011</td>
#       <td>0.863898</td>
#       <td>0.885000</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.783927</td>
#       <td>0.855532</td>
#       <td>0.890000</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.778552</td>
#       <td>0.854114</td>
#       <td>0.890556</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 1.109873652458191.
# Better model found at epoch 1 with val_loss value: 1.0190205574035645.
# Better model found at epoch 2 with val_loss value: 0.9748092293739319.
# Better model found at epoch 3 with val_loss value: 0.9244157075881958.
# Better model found at epoch 4 with val_loss value: 0.9153521060943604.
# Better model found at epoch 5 with val_loss value: 0.8943460583686829.
# Better model found at epoch 6 with val_loss value: 0.8731562495231628.
# Better model found at epoch 7 with val_loss value: 0.8638978004455566.
# Better model found at epoch 8 with val_loss value: 0.8555315732955933.
# Better model found at epoch 9 with val_loss value: 0.854114294052124.
# Evaluation size => test:(5000, 512), train(22500, 512)
# Calculated distances in shape (5000, 22500)
#
# Testing L2-constrainted for case #3
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.558517</td>
#       <td>1.502532</td>
#       <td>0.534333</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:13 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.210271</td>
#       <td>1.131937</td>
#       <td>0.734889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.086659</td>
#       <td>1.043567</td>
#       <td>0.778333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.051439</td>
#       <td>1.049836</td>
#       <td>0.776667</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.997146</td>
#       <td>0.984999</td>
#       <td>0.814778</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.949925</td>
#       <td>0.946063</td>
#       <td>0.834222</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.901725</td>
#       <td>0.929394</td>
#       <td>0.842000</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.868322</td>
#       <td>0.904697</td>
#       <td>0.859556</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.836242</td>
#       <td>0.898104</td>
#       <td>0.862111</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.807786</td>
#       <td>0.893569</td>
#       <td>0.868111</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.798910</td>
#       <td>0.885822</td>
#       <td>0.871444</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 1.13193678855896.
# Better model found at epoch 1 with val_loss value: 1.0435672998428345.
# Better model found at epoch 3 with val_loss value: 0.9849992394447327.
# Better model found at epoch 4 with val_loss value: 0.9460634589195251.
# Better model found at epoch 5 with val_loss value: 0.929394006729126.
# Better model found at epoch 6 with val_loss value: 0.9046968221664429.
# Better model found at epoch 7 with val_loss value: 0.8981042504310608.
# Better model found at epoch 8 with val_loss value: 0.8935690522193909.
# Better model found at epoch 9 with val_loss value: 0.8858222365379333.
# Evaluation size => test:(5000, 512), train(22500, 512)
# Calculated distances in shape (5000, 22500)
#
# Testing L2-constrainted for case #4
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.568002</td>
#       <td>1.518726</td>
#       <td>0.523444</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:13 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.222850</td>
#       <td>1.126657</td>
#       <td>0.735778</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.076525</td>
#       <td>1.078814</td>
#       <td>0.766667</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.035980</td>
#       <td>0.977350</td>
#       <td>0.817333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.972612</td>
#       <td>0.940977</td>
#       <td>0.838111</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.928091</td>
#       <td>0.922275</td>
#       <td>0.849222</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.882814</td>
#       <td>0.899325</td>
#       <td>0.864000</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.853313</td>
#       <td>0.891331</td>
#       <td>0.869778</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.818734</td>
#       <td>0.873230</td>
#       <td>0.878778</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.787375</td>
#       <td>0.864311</td>
#       <td>0.881889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.783093</td>
#       <td>0.867502</td>
#       <td>0.880000</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 1.1266571283340454.
# Better model found at epoch 1 with val_loss value: 1.0788135528564453.
# Better model found at epoch 2 with val_loss value: 0.9773504734039307.
# Better model found at epoch 3 with val_loss value: 0.9409765601158142.
# Better model found at epoch 4 with val_loss value: 0.9222753047943115.
# Better model found at epoch 5 with val_loss value: 0.8993249535560608.
# Better model found at epoch 6 with val_loss value: 0.8913305401802063.
# Better model found at epoch 7 with val_loss value: 0.8732302784919739.
# Better model found at epoch 8 with val_loss value: 0.8643113970756531.
# Evaluation size => test:(5000, 512), train(22500, 512)
# Calculated distances in shape (5000, 22500)
#
# Testing L2-constrainted for case #5
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.598243</td>
#       <td>1.527169</td>
#       <td>0.511889</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:13 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.237393</td>
#       <td>1.152139</td>
#       <td>0.717667</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.108063</td>
#       <td>1.046255</td>
#       <td>0.777556</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.076920</td>
#       <td>1.015459</td>
#       <td>0.794333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.024722</td>
#       <td>0.982812</td>
#       <td>0.812556</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.970792</td>
#       <td>0.964646</td>
#       <td>0.823556</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.921859</td>
#       <td>0.933333</td>
#       <td>0.840000</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.881408</td>
#       <td>0.927737</td>
#       <td>0.846889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.841381</td>
#       <td>0.916781</td>
#       <td>0.854111</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.822531</td>
#       <td>0.910361</td>
#       <td>0.853000</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.807438</td>
#       <td>0.909557</td>
#       <td>0.852889</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 1.1521388292312622.
# Better model found at epoch 1 with val_loss value: 1.0462547540664673.
# Better model found at epoch 2 with val_loss value: 1.015458583831787.
# Better model found at epoch 3 with val_loss value: 0.9828118681907654.
# Better model found at epoch 4 with val_loss value: 0.96464604139328.
# Better model found at epoch 5 with val_loss value: 0.9333329796791077.
# Better model found at epoch 6 with val_loss value: 0.9277374148368835.
# Better model found at epoch 7 with val_loss value: 0.9167805910110474.
# Better model found at epoch 8 with val_loss value: 0.9103613495826721.
# Better model found at epoch 9 with val_loss value: 0.9095567464828491.
# Evaluation size => test:(5000, 512), train(22500, 512)
# Calculated distances in shape (5000, 22500)
#
# Testing L2-constrainted for case #6
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.580634</td>
#       <td>1.527038</td>
#       <td>0.513556</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:13 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.240079</td>
#       <td>1.157705</td>
#       <td>0.717889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.114581</td>
#       <td>1.065219</td>
#       <td>0.766667</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.063055</td>
#       <td>1.005272</td>
#       <td>0.802222</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.013500</td>
#       <td>1.008923</td>
#       <td>0.802444</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.961341</td>
#       <td>0.978659</td>
#       <td>0.819778</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.922669</td>
#       <td>0.938695</td>
#       <td>0.841444</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.868624</td>
#       <td>0.915084</td>
#       <td>0.855667</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.835089</td>
#       <td>0.904930</td>
#       <td>0.860222</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.810054</td>
#       <td>0.905902</td>
#       <td>0.860444</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.795713</td>
#       <td>0.903731</td>
#       <td>0.862111</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 1.1577051877975464.
# Better model found at epoch 1 with val_loss value: 1.0652188062667847.
# Better model found at epoch 2 with val_loss value: 1.0052719116210938.
# Better model found at epoch 4 with val_loss value: 0.9786589741706848.
# Better model found at epoch 5 with val_loss value: 0.9386953115463257.
# Better model found at epoch 6 with val_loss value: 0.9150835275650024.
# Better model found at epoch 7 with val_loss value: 0.9049303531646729.
# Better model found at epoch 9 with val_loss value: 0.9037307500839233.
# Evaluation size => test:(5000, 512), train(22500, 512)
# Calculated distances in shape (5000, 22500)
#
# Testing L2-constrainted for case #7
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.573370</td>
#       <td>1.522321</td>
#       <td>0.523889</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:13 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.228539</td>
#       <td>1.171899</td>
#       <td>0.710000</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.106375</td>
#       <td>1.052659</td>
#       <td>0.771222</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.063021</td>
#       <td>1.069097</td>
#       <td>0.771000</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.009984</td>
#       <td>1.015119</td>
#       <td>0.799556</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.960531</td>
#       <td>0.972548</td>
#       <td>0.822889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.921027</td>
#       <td>0.938703</td>
#       <td>0.837556</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.873764</td>
#       <td>0.925824</td>
#       <td>0.848778</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.831465</td>
#       <td>0.904965</td>
#       <td>0.859556</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.813133</td>
#       <td>0.902000</td>
#       <td>0.865111</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.807692</td>
#       <td>0.903070</td>
#       <td>0.863000</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 1.171898603439331.
# Better model found at epoch 1 with val_loss value: 1.052659034729004.
# Better model found at epoch 3 with val_loss value: 1.015119194984436.
# Better model found at epoch 4 with val_loss value: 0.9725479483604431.
# Better model found at epoch 5 with val_loss value: 0.9387025833129883.
# Better model found at epoch 6 with val_loss value: 0.9258238077163696.
# Better model found at epoch 7 with val_loss value: 0.904964804649353.
# Better model found at epoch 8 with val_loss value: 0.9019995927810669.
# Evaluation size => test:(5000, 512), train(22500, 512)
# Calculated distances in shape (5000, 22500)
#
# Testing L2-constrainted for case #8
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.584963</td>
#       <td>1.540243</td>
#       <td>0.516333</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:13 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.253717</td>
#       <td>1.186143</td>
#       <td>0.706444</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.119877</td>
#       <td>1.047563</td>
#       <td>0.779000</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.081876</td>
#       <td>1.017299</td>
#       <td>0.797111</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.026943</td>
#       <td>1.007607</td>
#       <td>0.801000</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.979660</td>
#       <td>0.981526</td>
#       <td>0.815333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.931877</td>
#       <td>0.955905</td>
#       <td>0.829333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.876148</td>
#       <td>0.939696</td>
#       <td>0.840556</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.845410</td>
#       <td>0.926066</td>
#       <td>0.848778</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.825981</td>
#       <td>0.914836</td>
#       <td>0.854778</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.806890</td>
#       <td>0.911740</td>
#       <td>0.857000</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 1.1861430406570435.
# Better model found at epoch 1 with val_loss value: 1.0475629568099976.
# Better model found at epoch 2 with val_loss value: 1.0172988176345825.
# Better model found at epoch 3 with val_loss value: 1.0076072216033936.
# Better model found at epoch 4 with val_loss value: 0.9815258383750916.
# Better model found at epoch 5 with val_loss value: 0.9559051394462585.
# Better model found at epoch 6 with val_loss value: 0.9396963715553284.
# Better model found at epoch 7 with val_loss value: 0.9260656237602234.
# Better model found at epoch 8 with val_loss value: 0.9148356914520264.
# Better model found at epoch 9 with val_loss value: 0.9117400050163269.
# Evaluation size => test:(5000, 512), train(22500, 512)
# Calculated distances in shape (5000, 22500)
#
# Testing L2-constrainted for case #9
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.565339</td>
#       <td>1.533986</td>
#       <td>0.516222</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:13 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.255492</td>
#       <td>1.170987</td>
#       <td>0.712667</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.104312</td>
#       <td>1.052173</td>
#       <td>0.773333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.074183</td>
#       <td>1.047541</td>
#       <td>0.779778</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.026790</td>
#       <td>0.987710</td>
#       <td>0.812667</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.969294</td>
#       <td>0.977243</td>
#       <td>0.819667</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.918612</td>
#       <td>0.936389</td>
#       <td>0.843222</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.874388</td>
#       <td>0.929440</td>
#       <td>0.848222</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.836976</td>
#       <td>0.911438</td>
#       <td>0.859444</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.809020</td>
#       <td>0.901930</td>
#       <td>0.862889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.800196</td>
#       <td>0.902487</td>
#       <td>0.865778</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 1.1709867715835571.
# Better model found at epoch 1 with val_loss value: 1.0521727800369263.
# Better model found at epoch 2 with val_loss value: 1.0475407838821411.
# Better model found at epoch 3 with val_loss value: 0.987709641456604.
# Better model found at epoch 4 with val_loss value: 0.9772425293922424.
# Better model found at epoch 5 with val_loss value: 0.9363889098167419.
# Better model found at epoch 6 with val_loss value: 0.9294403195381165.
# Better model found at epoch 7 with val_loss value: 0.9114383459091187.
# Better model found at epoch 8 with val_loss value: 0.9019301533699036.
# Evaluation size => test:(5000, 512), train(22500, 512)
# Calculated distances in shape (5000, 22500)
# Deleting *.pth under /home/blmdr/lab/metric_learning/data_CIFAR10/images...

# %% [markdown]
# ## 3. ArcFace
#
# - J. Deng, J. Guo, and S. Zafeiriou. Arcface: Additive angular margin loss for deep face recognition. arXiv preprint arXiv:1801.07698, 2018. https://arxiv.org/pdf/1801.07698.pdf
# - Pytorch implementation: https://github.com/ronghuaiyang/arcface-pytorch

# %%
try:
    from metrics import *
except:
    ! wget https://raw.githubusercontent.com/ronghuaiyang/arcface-pytorch/master/models/metrics.py
    from metrics import *

# %%
class LabelCatcher(LearnerCallback):
    last_labels = None

    def __init__(self, learn:Learner):
        super().__init__(learn)
        
    def on_batch_begin(self, last_input, last_target, train, **kwargs):
        LabelCatcher.last_labels = last_target
        return {'last_input': last_input, 'last_target': last_target} 


class XFaceNet(nn.Module):
    def __init__(self, org_model, data, xface_product=ArcMarginProduct, m=0.5):
        super().__init__()
        self.org_model = org_model
        self.feature_model = body_feature_model(org_model)
        self.metric_fc = xface_product(512, data.c, m=m).cuda()
    
    def forward(self, x):
        x = self.feature_model(x)
        x = self.metric_fc(x, LabelCatcher.last_labels)
        return x


def learner_ArcFace(train_data):
    learn = cnn_learner(train_data, models.resnet18, metrics=accuracy)
    learn.model = XFaceNet(learn.model, train_data, ArcMarginProduct, m=0.5)
    learn.callback_fns.append(partial(LabelCatcher))
    learn.fit_one_cycle(1)
    learn.unfreeze()
    learn.fit_one_cycle(10, callbacks=[SaveModelCallback(learn)])
    return learn

if VISUALIZE_EMBEDDINGS:
    visualize_embeddings(learner_ArcFace(all_data), 'ArcFace (t-SNE)', all_data)
# Out:
# Total time: 00:13 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>14.995504</td>
#       <td>14.215503</td>
#       <td>0.044900</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:31 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>10.210663</td>
#       <td>9.329804</td>
#       <td>0.519600</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>8.425927</td>
#       <td>7.851749</td>
#       <td>0.647800</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>7.992038</td>
#       <td>8.137561</td>
#       <td>0.647300</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>7.474372</td>
#       <td>7.059592</td>
#       <td>0.678400</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>6.603631</td>
#       <td>7.210251</td>
#       <td>0.694300</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>5.942454</td>
#       <td>6.419675</td>
#       <td>0.730100</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>5.150226</td>
#       <td>5.820071</td>
#       <td>0.761200</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>4.642829</td>
#       <td>5.716335</td>
#       <td>0.773500</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>4.174117</td>
#       <td>5.297006</td>
#       <td>0.788800</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>3.998146</td>
#       <td>5.328219</td>
#       <td>0.791700</td>
#       <td>00:15</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 9.329804420471191.
# Better model found at epoch 1 with val_loss value: 7.851749420166016.
# Better model found at epoch 3 with val_loss value: 7.059592247009277.
# Better model found at epoch 5 with val_loss value: 6.419674873352051.
# Better model found at epoch 6 with val_loss value: 5.820070743560791.
# Better model found at epoch 7 with val_loss value: 5.716335296630859.
# Better model found at epoch 8 with val_loss value: 5.297006130218506.

# %%
toytest.do_tests('ArcFace', learner_ArcFace, delete_models=True)
# Out:
# Testing ArcFace for case #0
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>14.545101</td>
#       <td>13.511010</td>
#       <td>0.076111</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:18 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>9.363548</td>
#       <td>8.075283</td>
#       <td>0.570667</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>7.986712</td>
#       <td>7.293514</td>
#       <td>0.662333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>7.321331</td>
#       <td>7.337670</td>
#       <td>0.668444</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>6.890935</td>
#       <td>6.767173</td>
#       <td>0.704556</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>6.264724</td>
#       <td>6.139152</td>
#       <td>0.727444</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>5.351770</td>
#       <td>6.299620</td>
#       <td>0.746889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>4.869689</td>
#       <td>5.117408</td>
#       <td>0.792889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>4.296429</td>
#       <td>5.132244</td>
#       <td>0.795444</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>3.701295</td>
#       <td>4.943413</td>
#       <td>0.808333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>3.523703</td>
#       <td>4.884929</td>
#       <td>0.808778</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 8.07528305053711.
# Better model found at epoch 1 with val_loss value: 7.293513774871826.
# Better model found at epoch 3 with val_loss value: 6.767172813415527.
# Better model found at epoch 4 with val_loss value: 6.1391520500183105.
# Better model found at epoch 6 with val_loss value: 5.11740779876709.
# Better model found at epoch 8 with val_loss value: 4.943413257598877.
# Better model found at epoch 9 with val_loss value: 4.8849287033081055.
# Evaluation size => test:(5000, 512), train(22500, 512)
# Calculated distances in shape (5000, 22500)
#
# Testing ArcFace for case #1
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>14.498574</td>
#       <td>13.744338</td>
#       <td>0.089556</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:17 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>10.050704</td>
#       <td>8.771563</td>
#       <td>0.515889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>8.254895</td>
#       <td>8.564759</td>
#       <td>0.594667</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>8.036101</td>
#       <td>7.052775</td>
#       <td>0.652444</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>7.201572</td>
#       <td>7.780883</td>
#       <td>0.652111</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>6.576149</td>
#       <td>7.289858</td>
#       <td>0.675111</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>5.834715</td>
#       <td>6.266385</td>
#       <td>0.730778</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>4.987202</td>
#       <td>5.756610</td>
#       <td>0.766556</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>4.422695</td>
#       <td>5.587482</td>
#       <td>0.777444</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>4.078572</td>
#       <td>5.245441</td>
#       <td>0.790000</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>3.894219</td>
#       <td>5.211147</td>
#       <td>0.791667</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 8.771562576293945.
# Better model found at epoch 1 with val_loss value: 8.564759254455566.
# Better model found at epoch 2 with val_loss value: 7.0527753829956055.
# Better model found at epoch 5 with val_loss value: 6.266385078430176.
# Better model found at epoch 6 with val_loss value: 5.75661039352417.
# Better model found at epoch 7 with val_loss value: 5.587482452392578.
# Better model found at epoch 8 with val_loss value: 5.245441436767578.
# Better model found at epoch 9 with val_loss value: 5.211146831512451.
# Evaluation size => test:(5000, 512), train(22500, 512)
# Calculated distances in shape (5000, 22500)
#
# Testing ArcFace for case #2
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>14.623939</td>
#       <td>13.712187</td>
#       <td>0.070889</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:16 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>9.089142</td>
#       <td>8.181368</td>
#       <td>0.592222</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>7.242779</td>
#       <td>6.599009</td>
#       <td>0.713667</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>6.794998</td>
#       <td>7.049916</td>
#       <td>0.714889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>6.152178</td>
#       <td>6.816323</td>
#       <td>0.736333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>5.820471</td>
#       <td>6.024289</td>
#       <td>0.757444</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>4.679506</td>
#       <td>5.216906</td>
#       <td>0.796222</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>4.377659</td>
#       <td>5.199955</td>
#       <td>0.808778</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>3.664552</td>
#       <td>4.545050</td>
#       <td>0.828000</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>3.299584</td>
#       <td>4.321786</td>
#       <td>0.841333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>2.960428</td>
#       <td>4.242638</td>
#       <td>0.843000</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 8.181367874145508.
# Better model found at epoch 8 with val_loss value: 4.321786403656006.
# Better model found at epoch 9 with val_loss value: 4.242637634277344.
# Evaluation size => test:(5000, 512), train(22500, 512)
# Calculated distances in shape (5000, 22500)
#
# Testing ArcFace for case #3
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>14.521801</td>
#       <td>13.763053</td>
#       <td>0.088111</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:24 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>9.505630</td>
#       <td>8.401704</td>
#       <td>0.560556</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>7.776504</td>
#       <td>6.839756</td>
#       <td>0.672333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>7.320529</td>
#       <td>7.298860</td>
#       <td>0.670000</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>6.712955</td>
#       <td>6.896001</td>
#       <td>0.701000</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>6.108426</td>
#       <td>6.589569</td>
#       <td>0.734556</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>5.529714</td>
#       <td>5.620831</td>
#       <td>0.761667</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>4.786313</td>
#       <td>5.502513</td>
#       <td>0.771222</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>4.155277</td>
#       <td>4.983951</td>
#       <td>0.789556</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>3.798619</td>
#       <td>4.968152</td>
#       <td>0.800667</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>3.732642</td>
#       <td>4.885177</td>
#       <td>0.801778</td>
#       <td>00:15</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 8.401703834533691.
# Better model found at epoch 1 with val_loss value: 6.839756488800049.
# Better model found at epoch 4 with val_loss value: 6.589568614959717.
# Better model found at epoch 5 with val_loss value: 5.620830535888672.
# Better model found at epoch 6 with val_loss value: 5.5025129318237305.
# Better model found at epoch 7 with val_loss value: 4.983950614929199.
# Better model found at epoch 8 with val_loss value: 4.968152046203613.
# Better model found at epoch 9 with val_loss value: 4.885177135467529.
# Evaluation size => test:(5000, 512), train(22500, 512)
# Calculated distances in shape (5000, 22500)
#
# Testing ArcFace for case #4
# Total time: 00:13 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>14.767550</td>
#       <td>13.868015</td>
#       <td>0.067889</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:32 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>9.448229</td>
#       <td>8.182382</td>
#       <td>0.571000</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>7.654759</td>
#       <td>7.102577</td>
#       <td>0.677444</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>6.845817</td>
#       <td>7.363026</td>
#       <td>0.695111</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>6.281288</td>
#       <td>6.470963</td>
#       <td>0.726333</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>5.954456</td>
#       <td>6.569696</td>
#       <td>0.736222</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>5.001753</td>
#       <td>5.386836</td>
#       <td>0.785333</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>4.386011</td>
#       <td>5.091268</td>
#       <td>0.798556</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>3.836834</td>
#       <td>4.730672</td>
#       <td>0.808556</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>3.180526</td>
#       <td>4.481027</td>
#       <td>0.824778</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>3.148455</td>
#       <td>4.450780</td>
#       <td>0.826222</td>
#       <td>00:15</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 8.182381629943848.
# Better model found at epoch 1 with val_loss value: 7.102577209472656.
# Better model found at epoch 3 with val_loss value: 6.470963478088379.
# Better model found at epoch 5 with val_loss value: 5.386836051940918.
# Better model found at epoch 6 with val_loss value: 5.091268062591553.
# Better model found at epoch 7 with val_loss value: 4.730672359466553.
# Better model found at epoch 8 with val_loss value: 4.481027126312256.
# Better model found at epoch 9 with val_loss value: 4.450780391693115.
# Evaluation size => test:(5000, 512), train(22500, 512)
# Calculated distances in shape (5000, 22500)
#
# Testing ArcFace for case #5
# Total time: 00:13 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>14.922649</td>
#       <td>14.006408</td>
#       <td>0.020444</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:35 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>10.078758</td>
#       <td>8.690219</td>
#       <td>0.509111</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>8.184770</td>
#       <td>7.443668</td>
#       <td>0.667000</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>7.834198</td>
#       <td>7.401602</td>
#       <td>0.656222</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>7.009783</td>
#       <td>7.640623</td>
#       <td>0.689111</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>6.555751</td>
#       <td>6.476330</td>
#       <td>0.718667</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>5.845113</td>
#       <td>6.016464</td>
#       <td>0.731778</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>5.095430</td>
#       <td>5.682889</td>
#       <td>0.764444</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>4.525147</td>
#       <td>5.498019</td>
#       <td>0.779111</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>4.114355</td>
#       <td>5.226549</td>
#       <td>0.789333</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>4.004317</td>
#       <td>5.233071</td>
#       <td>0.793333</td>
#       <td>00:15</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 8.690218925476074.
# Better model found at epoch 1 with val_loss value: 7.443668365478516.
# Better model found at epoch 2 with val_loss value: 7.401601791381836.
# Better model found at epoch 4 with val_loss value: 6.476330280303955.
# Better model found at epoch 5 with val_loss value: 6.016463756561279.
# Better model found at epoch 6 with val_loss value: 5.682888507843018.
# Better model found at epoch 7 with val_loss value: 5.498019218444824.
# Better model found at epoch 8 with val_loss value: 5.226548671722412.
# Evaluation size => test:(5000, 512), train(22500, 512)
# Calculated distances in shape (5000, 22500)
#
# Testing ArcFace for case #6
# Total time: 00:13 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>14.889105</td>
#       <td>14.060405</td>
#       <td>0.040222</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:33 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>9.955531</td>
#       <td>9.182546</td>
#       <td>0.518000</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>8.053689</td>
#       <td>7.617708</td>
#       <td>0.651444</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>7.920074</td>
#       <td>8.763934</td>
#       <td>0.634556</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>7.174366</td>
#       <td>7.173139</td>
#       <td>0.684000</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>6.375461</td>
#       <td>7.032586</td>
#       <td>0.705556</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>5.734408</td>
#       <td>6.713103</td>
#       <td>0.732222</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>5.057053</td>
#       <td>5.788507</td>
#       <td>0.757667</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>4.574212</td>
#       <td>5.500569</td>
#       <td>0.778000</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>3.792263</td>
#       <td>5.272708</td>
#       <td>0.795333</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>3.611732</td>
#       <td>5.248064</td>
#       <td>0.793444</td>
#       <td>00:15</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 9.18254566192627.
# Better model found at epoch 1 with val_loss value: 7.617708206176758.
# Better model found at epoch 3 with val_loss value: 7.1731390953063965.
# Better model found at epoch 4 with val_loss value: 7.032586097717285.
# Better model found at epoch 5 with val_loss value: 6.7131028175354.
# Better model found at epoch 6 with val_loss value: 5.788507461547852.
# Better model found at epoch 7 with val_loss value: 5.5005693435668945.
# Better model found at epoch 8 with val_loss value: 5.272707939147949.
# Better model found at epoch 9 with val_loss value: 5.248063564300537.
# Evaluation size => test:(5000, 512), train(22500, 512)
# Calculated distances in shape (5000, 22500)
#
# Testing ArcFace for case #7
# Total time: 00:13 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>14.385747</td>
#       <td>13.632645</td>
#       <td>0.080333</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:39 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>9.807134</td>
#       <td>8.862744</td>
#       <td>0.507778</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>8.018373</td>
#       <td>8.064409</td>
#       <td>0.623111</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>7.763134</td>
#       <td>7.472401</td>
#       <td>0.648889</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>6.987264</td>
#       <td>7.203565</td>
#       <td>0.665222</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>6.234961</td>
#       <td>6.585505</td>
#       <td>0.735111</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>5.412013</td>
#       <td>5.953246</td>
#       <td>0.740667</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>4.918663</td>
#       <td>5.732535</td>
#       <td>0.763778</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>4.324609</td>
#       <td>5.255947</td>
#       <td>0.785889</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>4.065611</td>
#       <td>5.221180</td>
#       <td>0.791333</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>3.864091</td>
#       <td>5.067594</td>
#       <td>0.796444</td>
#       <td>00:15</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 8.862744331359863.
# Better model found at epoch 1 with val_loss value: 8.064409255981445.
# Better model found at epoch 2 with val_loss value: 7.472401142120361.
# Better model found at epoch 3 with val_loss value: 7.2035651206970215.
# Better model found at epoch 4 with val_loss value: 6.585504531860352.
# Better model found at epoch 5 with val_loss value: 5.953246116638184.
# Better model found at epoch 6 with val_loss value: 5.732534885406494.
# Better model found at epoch 7 with val_loss value: 5.255947113037109.
# Better model found at epoch 8 with val_loss value: 5.221179962158203.
# Better model found at epoch 9 with val_loss value: 5.067594051361084.
# Evaluation size => test:(5000, 512), train(22500, 512)
# Calculated distances in shape (5000, 22500)
#
# Testing ArcFace for case #8
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>14.592265</td>
#       <td>13.765806</td>
#       <td>0.099111</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:18 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>10.223598</td>
#       <td>9.441977</td>
#       <td>0.512000</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>8.548345</td>
#       <td>8.432018</td>
#       <td>0.630222</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>7.813254</td>
#       <td>8.789495</td>
#       <td>0.634778</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>7.134922</td>
#       <td>7.569382</td>
#       <td>0.684111</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>6.699306</td>
#       <td>7.107976</td>
#       <td>0.691667</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>5.984313</td>
#       <td>6.297065</td>
#       <td>0.742667</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>5.210781</td>
#       <td>5.965183</td>
#       <td>0.755778</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>4.718019</td>
#       <td>5.637415</td>
#       <td>0.773667</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>4.447035</td>
#       <td>5.569648</td>
#       <td>0.785000</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>4.167965</td>
#       <td>5.628505</td>
#       <td>0.782333</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 9.441976547241211.
# Better model found at epoch 1 with val_loss value: 8.432018280029297.
# Better model found at epoch 3 with val_loss value: 7.5693817138671875.
# Better model found at epoch 4 with val_loss value: 7.107975959777832.
# Better model found at epoch 5 with val_loss value: 6.297065258026123.
# Better model found at epoch 6 with val_loss value: 5.965183258056641.
# Better model found at epoch 7 with val_loss value: 5.637415409088135.
# Better model found at epoch 8 with val_loss value: 5.569647789001465.
# Evaluation size => test:(5000, 512), train(22500, 512)
# Calculated distances in shape (5000, 22500)
#
# Testing ArcFace for case #9
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>14.524632</td>
#       <td>13.649483</td>
#       <td>0.109444</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='6' class='' max='10', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       60.00% [6/10 01:23<00:55]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>10.081223</td>
#       <td>8.995932</td>
#       <td>0.516444</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>8.053774</td>
#       <td>8.125343</td>
#       <td>0.627556</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>7.692284</td>
#       <td>7.643779</td>
#       <td>0.653778</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>7.219272</td>
#       <td>7.346632</td>
#       <td>0.675444</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>6.393204</td>
#       <td>7.480529</td>
#       <td>0.680333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>5.621651</td>
#       <td>6.185838</td>
#       <td>0.734000</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='187' class='' max='703', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       26.60% [187/703 00:03<00:09 5.3408]
#     </div>
# Better model found at epoch 0 with val_loss value: 8.995931625366211.
# Better model found at epoch 1 with val_loss value: 8.125343322753906.
# Better model found at epoch 2 with val_loss value: 7.643779277801514.
# Better model found at epoch 3 with val_loss value: 7.34663200378418.
# Better model found at epoch 5 with val_loss value: 6.185837745666504.
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# ## 4. CosFace
# - H. Wang, Y. Wang, Z. Zhou, X. Ji, D. Gong, J. Zhou, Z. Li, and W. Liu, CosFace: Large Margin Cosine Loss for Deep Face Recognition, arXiv preprint arXiv:1801.09414, 2018. https://arxiv.org/pdf/1801.09414.pdf
# - Pytorch implementation: https://github.com/ronghuaiyang/arcface-pytorch

# %%
def learner_CosFace(train_data):
    learn = cnn_learner(train_data, models.resnet18, metrics=accuracy)
    learn.model = XFaceNet(learn.model, train_data, AddMarginProduct, m=0.4)
    learn.callback_fns.append(partial(LabelCatcher))
    learn.fit_one_cycle(1)
    learn.unfreeze()
    learn.fit_one_cycle(10, callbacks=[SaveModelCallback(learn)])
    return learn

if VISUALIZE_EMBEDDINGS:
    visualize_embeddings(learner_CosFace(all_data), 'CosFace (t-SNE)', all_data)
# Out:
# Total time: 00:13 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>12.511342</td>
#       <td>12.007037</td>
#       <td>0.083800</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:30 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>8.373659</td>
#       <td>8.054569</td>
#       <td>0.533400</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>7.136488</td>
#       <td>6.310266</td>
#       <td>0.647900</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>6.885113</td>
#       <td>7.142932</td>
#       <td>0.642000</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>6.009992</td>
#       <td>6.534469</td>
#       <td>0.661000</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>5.481886</td>
#       <td>5.713045</td>
#       <td>0.718600</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>4.789146</td>
#       <td>5.407113</td>
#       <td>0.741900</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>4.028469</td>
#       <td>5.037972</td>
#       <td>0.767000</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>3.390939</td>
#       <td>4.608711</td>
#       <td>0.789100</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>3.297049</td>
#       <td>4.473347</td>
#       <td>0.793900</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>2.906168</td>
#       <td>4.401586</td>
#       <td>0.797700</td>
#       <td>00:14</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 8.054569244384766.
# Better model found at epoch 1 with val_loss value: 6.310266494750977.
# Better model found at epoch 4 with val_loss value: 5.7130446434021.
# Better model found at epoch 5 with val_loss value: 5.407113075256348.
# Better model found at epoch 6 with val_loss value: 5.0379719734191895.
# Better model found at epoch 7 with val_loss value: 4.608710765838623.
# Better model found at epoch 8 with val_loss value: 4.473346710205078.
# Better model found at epoch 9 with val_loss value: 4.401586055755615.

# %%
toytest.do_tests('CosFace', learner_CosFace, delete_models=True)
# Out:
# Testing CosFace for case #0
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>12.132720</td>
#       <td>11.493099</td>
#       <td>0.125000</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:16 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>7.769567</td>
#       <td>7.123564</td>
#       <td>0.571333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>6.399610</td>
#       <td>7.105582</td>
#       <td>0.662778</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>6.180679</td>
#       <td>6.957510</td>
#       <td>0.673556</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>5.668511</td>
#       <td>5.087753</td>
#       <td>0.746667</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>5.048444</td>
#       <td>5.633783</td>
#       <td>0.738111</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>4.548944</td>
#       <td>4.685634</td>
#       <td>0.781556</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>3.858444</td>
#       <td>4.476544</td>
#       <td>0.795667</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>3.154684</td>
#       <td>4.178544</td>
#       <td>0.812778</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>2.801492</td>
#       <td>4.080030</td>
#       <td>0.819778</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>2.790323</td>
#       <td>4.152810</td>
#       <td>0.816889</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 7.12356424331665.
# Better model found at epoch 1 with val_loss value: 7.105581760406494.
# Better model found at epoch 2 with val_loss value: 6.957510471343994.
# Better model found at epoch 3 with val_loss value: 5.087752819061279.
# Better model found at epoch 5 with val_loss value: 4.685633659362793.
# Better model found at epoch 6 with val_loss value: 4.476544380187988.
# Better model found at epoch 7 with val_loss value: 4.178544044494629.
# Better model found at epoch 8 with val_loss value: 4.08003044128418.
# Evaluation size => test:(5000, 512), train(22500, 512)
# Calculated distances in shape (5000, 22500)
#
# Testing CosFace for case #1
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>12.102224</td>
#       <td>11.688167</td>
#       <td>0.148222</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:16 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>8.460352</td>
#       <td>8.080118</td>
#       <td>0.524111</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>6.876385</td>
#       <td>6.739058</td>
#       <td>0.647111</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>6.422703</td>
#       <td>6.344974</td>
#       <td>0.665444</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>6.171595</td>
#       <td>6.690061</td>
#       <td>0.672889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>5.452904</td>
#       <td>5.328065</td>
#       <td>0.725111</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>4.729188</td>
#       <td>5.290266</td>
#       <td>0.751667</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>4.254613</td>
#       <td>4.607882</td>
#       <td>0.780778</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>3.488112</td>
#       <td>4.479434</td>
#       <td>0.792667</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>3.053017</td>
#       <td>4.326711</td>
#       <td>0.799667</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>3.049782</td>
#       <td>4.403343</td>
#       <td>0.797667</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 8.080118179321289.
# Better model found at epoch 1 with val_loss value: 6.739058017730713.
# Better model found at epoch 2 with val_loss value: 6.344974040985107.
# Better model found at epoch 4 with val_loss value: 5.328064918518066.
# Better model found at epoch 5 with val_loss value: 5.2902655601501465.
# Better model found at epoch 6 with val_loss value: 4.607882022857666.
# Better model found at epoch 7 with val_loss value: 4.479433536529541.
# Better model found at epoch 8 with val_loss value: 4.3267107009887695.
# Evaluation size => test:(5000, 512), train(22500, 512)
# Calculated distances in shape (5000, 22500)
#
# Testing CosFace for case #2
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>12.136706</td>
#       <td>11.543248</td>
#       <td>0.124667</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='8' class='' max='10', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       80.00% [8/10 01:49<00:27]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>7.373869</td>
#       <td>6.802761</td>
#       <td>0.616333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>6.186644</td>
#       <td>5.853559</td>
#       <td>0.706333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>5.872938</td>
#       <td>7.111038</td>
#       <td>0.670222</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>5.270348</td>
#       <td>5.726045</td>
#       <td>0.729556</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>4.690901</td>
#       <td>4.699100</td>
#       <td>0.781889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>3.748194</td>
#       <td>4.289085</td>
#       <td>0.806889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>3.370065</td>
#       <td>3.943884</td>
#       <td>0.819778</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>2.706752</td>
#       <td>3.649995</td>
#       <td>0.831444</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='61' class='' max='703', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       8.68% [61/703 00:01<00:14 2.4158]
#     </div>
# Better model found at epoch 0 with val_loss value: 6.802760601043701.
# Better model found at epoch 1 with val_loss value: 5.8535590171813965.
# Better model found at epoch 3 with val_loss value: 5.72604513168335.
# Better model found at epoch 4 with val_loss value: 4.699100017547607.
# Better model found at epoch 5 with val_loss value: 4.289085388183594.
# Better model found at epoch 6 with val_loss value: 3.9438841342926025.
# Better model found at epoch 7 with val_loss value: 3.6499953269958496.
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Calculated distances in shape (5000, 22500)
#
# Testing CosFace for case #5
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>12.479683</td>
#       <td>11.781467</td>
#       <td>0.062556</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:15 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>8.575922</td>
#       <td>7.542936</td>
#       <td>0.538000</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>7.059580</td>
#       <td>6.875497</td>
#       <td>0.633333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>6.580602</td>
#       <td>6.511827</td>
#       <td>0.657889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>5.939027</td>
#       <td>6.227642</td>
#       <td>0.692778</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>5.328894</td>
#       <td>5.561482</td>
#       <td>0.738000</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>4.789289</td>
#       <td>5.132843</td>
#       <td>0.750778</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>3.869857</td>
#       <td>4.859670</td>
#       <td>0.768111</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>3.473021</td>
#       <td>4.457516</td>
#       <td>0.790778</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>2.984868</td>
#       <td>4.313465</td>
#       <td>0.803111</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>2.904601</td>
#       <td>4.299111</td>
#       <td>0.803556</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 7.542935848236084.
# Better model found at epoch 1 with val_loss value: 6.875497341156006.
# Better model found at epoch 2 with val_loss value: 6.51182746887207.
# Better model found at epoch 3 with val_loss value: 6.227641582489014.
# Better model found at epoch 4 with val_loss value: 5.561481952667236.
# Better model found at epoch 5 with val_loss value: 5.132843494415283.
# Better model found at epoch 6 with val_loss value: 4.859670162200928.
# Better model found at epoch 7 with val_loss value: 4.457515716552734.
# Better model found at epoch 8 with val_loss value: 4.313464641571045.
# Better model found at epoch 9 with val_loss value: 4.2991108894348145.
# Evaluation size => test:(5000, 512), train(22500, 512)
# Calculated distances in shape (5000, 22500)
#
# Testing CosFace for case #6
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>12.293047</td>
#       <td>11.953723</td>
#       <td>0.109333</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:13 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>8.411760</td>
#       <td>7.881748</td>
#       <td>0.538000</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>6.884694</td>
#       <td>7.092771</td>
#       <td>0.648111</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>6.547898</td>
#       <td>7.148629</td>
#       <td>0.666222</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>6.008329</td>
#       <td>5.906645</td>
#       <td>0.710444</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>5.343494</td>
#       <td>6.017286</td>
#       <td>0.719778</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>4.389966</td>
#       <td>6.262757</td>
#       <td>0.723000</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>3.832640</td>
#       <td>4.700727</td>
#       <td>0.783556</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>3.496265</td>
#       <td>4.512643</td>
#       <td>0.790889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>3.115941</td>
#       <td>4.402319</td>
#       <td>0.797889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>2.997615</td>
#       <td>4.472862</td>
#       <td>0.798556</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 7.881748199462891.
# Better model found at epoch 1 with val_loss value: 7.092770576477051.
# Better model found at epoch 3 with val_loss value: 5.90664529800415.
# Better model found at epoch 6 with val_loss value: 4.700726509094238.
# Better model found at epoch 7 with val_loss value: 4.512643337249756.
# Better model found at epoch 8 with val_loss value: 4.402318954467773.
# Evaluation size => test:(5000, 512), train(22500, 512)
# Calculated distances in shape (5000, 22500)
#
# Testing CosFace for case #7
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>12.232443</td>
#       <td>11.531837</td>
#       <td>0.128111</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:14 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>8.205132</td>
#       <td>7.774400</td>
#       <td>0.543667</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>6.681163</td>
#       <td>6.821705</td>
#       <td>0.657444</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>6.543446</td>
#       <td>6.053108</td>
#       <td>0.662667</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>5.593091</td>
#       <td>6.244077</td>
#       <td>0.694222</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>5.169137</td>
#       <td>5.700645</td>
#       <td>0.726889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>4.442125</td>
#       <td>5.255901</td>
#       <td>0.753778</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>4.050943</td>
#       <td>5.107549</td>
#       <td>0.768778</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>3.500393</td>
#       <td>4.441876</td>
#       <td>0.797333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>3.266483</td>
#       <td>4.338517</td>
#       <td>0.804889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>2.790728</td>
#       <td>4.304687</td>
#       <td>0.806111</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 7.774400234222412.
# Better model found at epoch 1 with val_loss value: 6.821704864501953.
# Better model found at epoch 2 with val_loss value: 6.053107738494873.
# Better model found at epoch 4 with val_loss value: 5.700645446777344.
# Better model found at epoch 5 with val_loss value: 5.255900859832764.
# Better model found at epoch 6 with val_loss value: 5.107548713684082.
# Better model found at epoch 7 with val_loss value: 4.441876411437988.
# Better model found at epoch 8 with val_loss value: 4.338516712188721.
# Better model found at epoch 9 with val_loss value: 4.304686546325684.
# Evaluation size => test:(5000, 512), train(22500, 512)
# Calculated distances in shape (5000, 22500)
#
# Testing CosFace for case #8
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>12.246095</td>
#       <td>11.636611</td>
#       <td>0.129111</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='9' class='' max='10', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       90.00% [9/10 02:01<00:13]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>8.525612</td>
#       <td>7.778420</td>
#       <td>0.533667</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>6.940533</td>
#       <td>6.683547</td>
#       <td>0.649222</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>6.627703</td>
#       <td>6.969773</td>
#       <td>0.652333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>6.211745</td>
#       <td>6.080111</td>
#       <td>0.699667</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>5.438181</td>
#       <td>6.099583</td>
#       <td>0.705333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>4.753732</td>
#       <td>5.229296</td>
#       <td>0.759667</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>4.142741</td>
#       <td>4.898063</td>
#       <td>0.767333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>3.505928</td>
#       <td>4.622897</td>
#       <td>0.786333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>3.140608</td>
#       <td>4.544217</td>
#       <td>0.792222</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='702' class='' max='703', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       99.86% [702/703 00:12<00:00 2.9491]
#     </div>
# Better model found at epoch 0 with val_loss value: 7.7784199714660645.
# Better model found at epoch 1 with val_loss value: 6.683546543121338.
# Better model found at epoch 3 with val_loss value: 6.080110549926758.
# Better model found at epoch 5 with val_loss value: 5.2292962074279785.
# Better model found at epoch 6 with val_loss value: 4.898062705993652.
# Better model found at epoch 7 with val_loss value: 4.622896671295166.
# Better model found at epoch 8 with val_loss value: 4.544217109680176.
# Better model found at epoch 1 with val_loss value: 6.460289001464844.
# Better model found at epoch 3 with val_loss value: 5.767247676849365.
# Better model found at epoch 4 with val_loss value: 5.529308795928955.
# Better model found at epoch 5 with val_loss value: 5.153416633605957.
# Better model found at epoch 6 with val_loss value: 4.976151943206787.
# Better model found at epoch 7 with val_loss value: 4.4817795753479.
# Better model found at epoch 8 with val_loss value: 4.317196369171143.
# Evaluation size => test:(5000, 512), train(22500, 512)
# Calculated distances in shape (5000, 22500)
# Deleting *.pth under /home/blmdr/lab/metric_learning/data_CIFAR10/images...

# %% [markdown]
# ## 5. SphereFace
#
# - W. Liu, Y. Wen, Z. Yu, M. Li, B. Raj, and L. Song. SphereFace: Deep Hypersphere Embedding for Face Recognition. In CVPR, 2017. https://arxiv.org/pdf/1704.08063.pdf
# - Pytorch implementation: https://github.com/ronghuaiyang/arcface-pytorch

# %%
def learner_SphereFace(train_data):
    learn = cnn_learner(train_data, models.resnet18, metrics=accuracy)
    learn.model = XFaceNet(learn.model, train_data, SphereProduct, m=int(4))
    learn.callback_fns.append(partial(LabelCatcher))
    learn.fit_one_cycle(1)
    learn.unfreeze()
    learn.fit_one_cycle(10, callbacks=[SaveModelCallback(learn)])
    return learn

if VISUALIZE_EMBEDDINGS:
    visualize_embeddings(learner_SphereFace(all_data), 'SphereFace (t-SNE)', all_data)
# Out:
# Total time: 00:13 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.303617</td>
#       <td>2.041019</td>
#       <td>0.314200</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:32 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.887535</td>
#       <td>1.431835</td>
#       <td>0.640600</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.604822</td>
#       <td>1.185693</td>
#       <td>0.713100</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.491357</td>
#       <td>1.196198</td>
#       <td>0.720300</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.384116</td>
#       <td>1.045142</td>
#       <td>0.748000</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.204252</td>
#       <td>0.967710</td>
#       <td>0.775800</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.076473</td>
#       <td>0.904444</td>
#       <td>0.795400</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.953823</td>
#       <td>0.883151</td>
#       <td>0.805000</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.760190</td>
#       <td>0.858078</td>
#       <td>0.821700</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.666502</td>
#       <td>0.838959</td>
#       <td>0.827900</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.650556</td>
#       <td>0.832367</td>
#       <td>0.829200</td>
#       <td>00:15</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 1.4318351745605469.
# Better model found at epoch 1 with val_loss value: 1.185693383216858.
# Better model found at epoch 3 with val_loss value: 1.045142412185669.
# Better model found at epoch 4 with val_loss value: 0.9677095413208008.
# Better model found at epoch 5 with val_loss value: 0.9044443368911743.
# Better model found at epoch 6 with val_loss value: 0.8831506967544556.
# Better model found at epoch 7 with val_loss value: 0.858078122138977.
# Better model found at epoch 8 with val_loss value: 0.8389591574668884.
# Better model found at epoch 9 with val_loss value: 0.8323665857315063.

# %%
toytest.do_tests('ShpereFace', learner_SphereFace, delete_models=True)
# Out:
# Testing ShpereFace for case #0
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.200973</td>
#       <td>1.914060</td>
#       <td>0.341556</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:19 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.731554</td>
#       <td>1.280578</td>
#       <td>0.674556</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.454421</td>
#       <td>1.125053</td>
#       <td>0.725556</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.369224</td>
#       <td>0.991228</td>
#       <td>0.761889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.207076</td>
#       <td>0.911082</td>
#       <td>0.782667</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.085653</td>
#       <td>0.887265</td>
#       <td>0.796000</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.938402</td>
#       <td>0.804766</td>
#       <td>0.815333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.815078</td>
#       <td>0.768356</td>
#       <td>0.831333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.676903</td>
#       <td>0.763552</td>
#       <td>0.841111</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.551660</td>
#       <td>0.752038</td>
#       <td>0.843556</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.530536</td>
#       <td>0.747862</td>
#       <td>0.849111</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 1.2805776596069336.
# Better model found at epoch 1 with val_loss value: 1.125052571296692.
# Better model found at epoch 2 with val_loss value: 0.9912281036376953.
# Better model found at epoch 3 with val_loss value: 0.9110820293426514.
# Better model found at epoch 4 with val_loss value: 0.8872650265693665.
# Better model found at epoch 5 with val_loss value: 0.8047656416893005.
# Better model found at epoch 6 with val_loss value: 0.7683559060096741.
# Better model found at epoch 7 with val_loss value: 0.7635523676872253.
# Better model found at epoch 8 with val_loss value: 0.7520376443862915.
# Better model found at epoch 9 with val_loss value: 0.7478616833686829.
# Evaluation size => test:(5000, 512), train(22500, 512)
# Calculated distances in shape (5000, 22500)
#
# Testing ShpereFace for case #1
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.203812</td>
#       <td>1.954160</td>
#       <td>0.349222</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:19 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.790286</td>
#       <td>1.387923</td>
#       <td>0.639333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.551231</td>
#       <td>1.160887</td>
#       <td>0.716333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.428555</td>
#       <td>1.136761</td>
#       <td>0.720889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.312709</td>
#       <td>1.001420</td>
#       <td>0.757889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.175112</td>
#       <td>0.928876</td>
#       <td>0.776444</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.968623</td>
#       <td>0.903256</td>
#       <td>0.793222</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.874996</td>
#       <td>0.836288</td>
#       <td>0.811000</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.758958</td>
#       <td>0.804524</td>
#       <td>0.821111</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.659801</td>
#       <td>0.788194</td>
#       <td>0.830111</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.596567</td>
#       <td>0.809899</td>
#       <td>0.828667</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 1.3879225254058838.
# Better model found at epoch 1 with val_loss value: 1.160887360572815.
# Better model found at epoch 2 with val_loss value: 1.136760950088501.
# Better model found at epoch 3 with val_loss value: 1.0014196634292603.
# Better model found at epoch 4 with val_loss value: 0.9288762211799622.
# Better model found at epoch 5 with val_loss value: 0.9032555222511292.
# Better model found at epoch 6 with val_loss value: 0.8362876772880554.
# Better model found at epoch 7 with val_loss value: 0.8045240640640259.
# Better model found at epoch 8 with val_loss value: 0.7881937623023987.
# Evaluation size => test:(5000, 512), train(22500, 512)
# Calculated distances in shape (5000, 22500)
#
# Testing ShpereFace for case #2
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.212050</td>
#       <td>1.908303</td>
#       <td>0.352000</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:18 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.706715</td>
#       <td>1.246243</td>
#       <td>0.692111</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.438325</td>
#       <td>1.039062</td>
#       <td>0.753889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.306625</td>
#       <td>1.038513</td>
#       <td>0.760556</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.203671</td>
#       <td>0.962994</td>
#       <td>0.789222</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.051692</td>
#       <td>0.900492</td>
#       <td>0.799667</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.896488</td>
#       <td>0.714604</td>
#       <td>0.846556</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.741445</td>
#       <td>0.669132</td>
#       <td>0.852222</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.573522</td>
#       <td>0.661684</td>
#       <td>0.860556</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.493844</td>
#       <td>0.643986</td>
#       <td>0.868778</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.435288</td>
#       <td>0.659219</td>
#       <td>0.867333</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 1.246242642402649.
# Better model found at epoch 1 with val_loss value: 1.0390623807907104.
# Better model found at epoch 2 with val_loss value: 1.0385130643844604.
# Better model found at epoch 3 with val_loss value: 0.9629942774772644.
# Better model found at epoch 4 with val_loss value: 0.9004924893379211.
# Better model found at epoch 5 with val_loss value: 0.7146039605140686.
# Better model found at epoch 6 with val_loss value: 0.6691320538520813.
# Better model found at epoch 7 with val_loss value: 0.6616836786270142.
# Better model found at epoch 8 with val_loss value: 0.6439863443374634.
# Evaluation size => test:(5000, 512), train(22500, 512)
# Calculated distances in shape (5000, 22500)
#
# Testing ShpereFace for case #3
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.186806</td>
#       <td>1.913452</td>
#       <td>0.331333</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:18 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.677241</td>
#       <td>1.255840</td>
#       <td>0.674000</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.422489</td>
#       <td>1.061808</td>
#       <td>0.738889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.389878</td>
#       <td>1.054922</td>
#       <td>0.736111</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.249396</td>
#       <td>0.941897</td>
#       <td>0.768222</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.120364</td>
#       <td>0.883492</td>
#       <td>0.789444</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.966119</td>
#       <td>0.840682</td>
#       <td>0.801444</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.790123</td>
#       <td>0.810705</td>
#       <td>0.814333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.682347</td>
#       <td>0.746185</td>
#       <td>0.828333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.600073</td>
#       <td>0.759014</td>
#       <td>0.835889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.561652</td>
#       <td>0.748373</td>
#       <td>0.840000</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 1.2558395862579346.
# Better model found at epoch 1 with val_loss value: 1.0618083477020264.
# Better model found at epoch 2 with val_loss value: 1.0549219846725464.
# Better model found at epoch 3 with val_loss value: 0.9418966770172119.
# Better model found at epoch 4 with val_loss value: 0.8834916353225708.
# Better model found at epoch 5 with val_loss value: 0.8406820893287659.
# Better model found at epoch 6 with val_loss value: 0.810705304145813.
# Better model found at epoch 7 with val_loss value: 0.7461850643157959.
# Evaluation size => test:(5000, 512), train(22500, 512)
# Calculated distances in shape (5000, 22500)
#
# Testing ShpereFace for case #4
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.209128</td>
#       <td>1.930636</td>
#       <td>0.339333</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:18 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.726156</td>
#       <td>1.266523</td>
#       <td>0.686778</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.452298</td>
#       <td>1.051362</td>
#       <td>0.755889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.351216</td>
#       <td>1.006480</td>
#       <td>0.767889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.180186</td>
#       <td>0.898701</td>
#       <td>0.801333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.055910</td>
#       <td>0.840074</td>
#       <td>0.812222</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.875764</td>
#       <td>0.787451</td>
#       <td>0.827667</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.742704</td>
#       <td>0.797027</td>
#       <td>0.835333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.608367</td>
#       <td>0.726739</td>
#       <td>0.849222</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.507988</td>
#       <td>0.735495</td>
#       <td>0.855333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.472776</td>
#       <td>0.744873</td>
#       <td>0.860000</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 1.2665231227874756.
# Better model found at epoch 1 with val_loss value: 1.051362156867981.
# Better model found at epoch 2 with val_loss value: 1.00648033618927.
# Better model found at epoch 3 with val_loss value: 0.8987010717391968.
# Better model found at epoch 4 with val_loss value: 0.8400736451148987.
# Better model found at epoch 5 with val_loss value: 0.7874506115913391.
# Better model found at epoch 7 with val_loss value: 0.7267385721206665.
# Evaluation size => test:(5000, 512), train(22500, 512)
# Calculated distances in shape (5000, 22500)
#
# Testing ShpereFace for case #5
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.282108</td>
#       <td>1.978547</td>
#       <td>0.298333</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:18 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.826969</td>
#       <td>1.370739</td>
#       <td>0.650333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.539078</td>
#       <td>1.125902</td>
#       <td>0.727444</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.440420</td>
#       <td>1.107053</td>
#       <td>0.740556</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.323085</td>
#       <td>1.016085</td>
#       <td>0.762333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.144556</td>
#       <td>0.979932</td>
#       <td>0.769556</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.017629</td>
#       <td>0.899020</td>
#       <td>0.786333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.876180</td>
#       <td>0.822546</td>
#       <td>0.813889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.741831</td>
#       <td>0.795181</td>
#       <td>0.826222</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.640011</td>
#       <td>0.788349</td>
#       <td>0.831111</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.616975</td>
#       <td>0.796981</td>
#       <td>0.833000</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 1.3707389831542969.
# Better model found at epoch 1 with val_loss value: 1.1259015798568726.
# Better model found at epoch 2 with val_loss value: 1.1070525646209717.
# Better model found at epoch 3 with val_loss value: 1.0160846710205078.
# Better model found at epoch 4 with val_loss value: 0.979931652545929.
# Better model found at epoch 5 with val_loss value: 0.8990197777748108.
# Better model found at epoch 6 with val_loss value: 0.8225457072257996.
# Better model found at epoch 7 with val_loss value: 0.7951814532279968.
# Better model found at epoch 8 with val_loss value: 0.7883485555648804.
# Evaluation size => test:(5000, 512), train(22500, 512)
# Calculated distances in shape (5000, 22500)
#
# Testing ShpereFace for case #6
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.294705</td>
#       <td>2.004559</td>
#       <td>0.301556</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:18 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.801247</td>
#       <td>1.393250</td>
#       <td>0.627556</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.535261</td>
#       <td>1.186264</td>
#       <td>0.710333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.425275</td>
#       <td>1.164327</td>
#       <td>0.711889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.300665</td>
#       <td>1.031384</td>
#       <td>0.745556</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.137254</td>
#       <td>0.957974</td>
#       <td>0.773222</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.023471</td>
#       <td>0.871172</td>
#       <td>0.799222</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.881835</td>
#       <td>0.856629</td>
#       <td>0.809667</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.718564</td>
#       <td>0.834654</td>
#       <td>0.821333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.620439</td>
#       <td>0.796649</td>
#       <td>0.832889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.576745</td>
#       <td>0.807468</td>
#       <td>0.834444</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 1.3932501077651978.
# Better model found at epoch 1 with val_loss value: 1.1862635612487793.
# Better model found at epoch 2 with val_loss value: 1.1643272638320923.
# Better model found at epoch 3 with val_loss value: 1.0313841104507446.
# Better model found at epoch 4 with val_loss value: 0.9579741954803467.
# Better model found at epoch 5 with val_loss value: 0.871171772480011.
# Better model found at epoch 6 with val_loss value: 0.8566287755966187.
# Better model found at epoch 7 with val_loss value: 0.8346539735794067.
# Better model found at epoch 8 with val_loss value: 0.7966488599777222.
# Evaluation size => test:(5000, 512), train(22500, 512)
# Calculated distances in shape (5000, 22500)
#
# Testing ShpereFace for case #7
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.224754</td>
#       <td>1.943445</td>
#       <td>0.335222</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:17 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.782054</td>
#       <td>1.364795</td>
#       <td>0.642556</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.542690</td>
#       <td>1.193937</td>
#       <td>0.709556</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.389953</td>
#       <td>1.082159</td>
#       <td>0.730444</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.284403</td>
#       <td>1.016227</td>
#       <td>0.754222</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.139635</td>
#       <td>1.011003</td>
#       <td>0.766889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.960684</td>
#       <td>0.876560</td>
#       <td>0.792000</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.826269</td>
#       <td>0.835369</td>
#       <td>0.817000</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.681956</td>
#       <td>0.809816</td>
#       <td>0.822556</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.649985</td>
#       <td>0.804855</td>
#       <td>0.828889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.568374</td>
#       <td>0.782381</td>
#       <td>0.835444</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 1.3647953271865845.
# Better model found at epoch 1 with val_loss value: 1.1939374208450317.
# Better model found at epoch 2 with val_loss value: 1.0821586847305298.
# Better model found at epoch 3 with val_loss value: 1.0162272453308105.
# Better model found at epoch 4 with val_loss value: 1.011002540588379.
# Better model found at epoch 5 with val_loss value: 0.8765604496002197.
# Better model found at epoch 6 with val_loss value: 0.8353691697120667.
# Better model found at epoch 7 with val_loss value: 0.8098156452178955.
# Better model found at epoch 8 with val_loss value: 0.804855465888977.
# Better model found at epoch 9 with val_loss value: 0.7823811769485474.
# Evaluation size => test:(5000, 512), train(22500, 512)
# Calculated distances in shape (5000, 22500)
#
# Testing ShpereFace for case #8
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.244341</td>
#       <td>1.950838</td>
#       <td>0.337444</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:16 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.818648</td>
#       <td>1.408728</td>
#       <td>0.626889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.557513</td>
#       <td>1.185347</td>
#       <td>0.709111</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.460737</td>
#       <td>1.324519</td>
#       <td>0.675778</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.310486</td>
#       <td>0.984187</td>
#       <td>0.766333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.135079</td>
#       <td>1.034035</td>
#       <td>0.760222</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.989556</td>
#       <td>0.851028</td>
#       <td>0.802000</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.899611</td>
#       <td>0.875014</td>
#       <td>0.802333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.777041</td>
#       <td>0.831524</td>
#       <td>0.815222</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.624842</td>
#       <td>0.809744</td>
#       <td>0.826667</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.631086</td>
#       <td>0.832301</td>
#       <td>0.827667</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 1.408727765083313.
# Better model found at epoch 1 with val_loss value: 1.1853468418121338.
# Better model found at epoch 3 with val_loss value: 0.9841870665550232.
# Better model found at epoch 5 with val_loss value: 0.8510276675224304.
# Better model found at epoch 7 with val_loss value: 0.8315241932868958.
# Better model found at epoch 8 with val_loss value: 0.809744119644165.
# Evaluation size => test:(5000, 512), train(22500, 512)
# Calculated distances in shape (5000, 22500)
#
# Testing ShpereFace for case #9
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.191683</td>
#       <td>1.953321</td>
#       <td>0.341778</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:16 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.777937</td>
#       <td>1.395702</td>
#       <td>0.644111</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.548418</td>
#       <td>1.207325</td>
#       <td>0.700889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.420609</td>
#       <td>1.139529</td>
#       <td>0.733667</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.314671</td>
#       <td>0.979153</td>
#       <td>0.766222</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.163078</td>
#       <td>0.933647</td>
#       <td>0.779667</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.998890</td>
#       <td>0.931732</td>
#       <td>0.783889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.851042</td>
#       <td>0.829458</td>
#       <td>0.812333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.735768</td>
#       <td>0.770110</td>
#       <td>0.830333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.602685</td>
#       <td>0.789339</td>
#       <td>0.833111</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.565202</td>
#       <td>0.814736</td>
#       <td>0.830333</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 1.3957017660140991.
# Better model found at epoch 1 with val_loss value: 1.2073253393173218.
# Better model found at epoch 2 with val_loss value: 1.1395286321640015.
# Better model found at epoch 3 with val_loss value: 0.9791534543037415.
# Better model found at epoch 4 with val_loss value: 0.9336471557617188.
# Better model found at epoch 5 with val_loss value: 0.931731641292572.
# Better model found at epoch 6 with val_loss value: 0.8294584155082703.
# Better model found at epoch 7 with val_loss value: 0.7701095938682556.
# Evaluation size => test:(5000, 512), train(22500, 512)
# Calculated distances in shape (5000, 22500)
# Deleting *.pth under /home/blmdr/lab/metric_learning/data_CIFAR10/images...

# %% [markdown]
# ## 6. Center Loss
#
# - Y. Wen, K. Zhang, Z. Li, and Y. Qiao, A discriminative feature learning approach for deep face recognition,” in European Conference on Computer Vision. Springer, 2016, pp. 499–515. https://ydwen.github.io/papers/WenECCV16.pdf
# - Pytorch implementation: https://github.com/KaiyangZhou/pytorch-center-loss

# %%
try:
    from center_loss import *
except:
    ! wget https://raw.githubusercontent.com/KaiyangZhou/pytorch-center-loss/master/center_loss.py
    from center_loss import *

# %%
class WrapCenterLoss(nn.Module):
    "CenterLoss wrapper for https://github.com/KaiyangZhou/pytorch-center-loss."
    
    def __init__(self, learn, data, weight_cent=1/10):
        super().__init__()
        self.org_loss = learn.loss_func
        self.center_loss = CenterLoss(data.c, data.c)
        self.weight_cent = weight_cent

    def forward(self, output, target):
        dL = self.org_loss(output, target)
        dC = self.center_loss(output, target)
        #print(dL, dC)
        d = dL + self.weight_cent * dC
        return d

def learner_CenterLoss(train_data):
    learn = cnn_learner(train_data, models.resnet18, metrics=accuracy)
    learn.loss_func = WrapCenterLoss(learn, train_data, weight_cent=1/8) ## Hand tuned
    learn.fit_one_cycle(1)
    learn.unfreeze()
    learn.fit_one_cycle(10, callbacks=[SaveModelCallback(learn)])
    return learn

if VISUALIZE_EMBEDDINGS:
    visualize_embeddings(learner_CenterLoss(all_data), 'CenterLoss (t-SNE)', all_data)
# Out:
# Total time: 00:12 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.167843</td>
#       <td>3.051461</td>
#       <td>0.396400</td>
#       <td>00:12</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:29 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.553089</td>
#       <td>2.360490</td>
#       <td>0.671500</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.318432</td>
#       <td>2.175803</td>
#       <td>0.742100</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.229244</td>
#       <td>2.097430</td>
#       <td>0.762600</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.110512</td>
#       <td>2.090586</td>
#       <td>0.771300</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.016207</td>
#       <td>1.985742</td>
#       <td>0.805400</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.921980</td>
#       <td>1.911410</td>
#       <td>0.818600</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.805993</td>
#       <td>1.873405</td>
#       <td>0.836000</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.732669</td>
#       <td>1.850464</td>
#       <td>0.843200</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.662092</td>
#       <td>1.834956</td>
#       <td>0.848500</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.649007</td>
#       <td>1.833374</td>
#       <td>0.848400</td>
#       <td>00:14</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 2.360490322113037.
# Better model found at epoch 1 with val_loss value: 2.1758029460906982.
# Better model found at epoch 2 with val_loss value: 2.0974299907684326.
# Better model found at epoch 3 with val_loss value: 2.090585947036743.
# Better model found at epoch 4 with val_loss value: 1.985742211341858.
# Better model found at epoch 5 with val_loss value: 1.9114102125167847.
# Better model found at epoch 6 with val_loss value: 1.8734054565429688.
# Better model found at epoch 7 with val_loss value: 1.8504644632339478.
# Better model found at epoch 8 with val_loss value: 1.8349558115005493.
# Better model found at epoch 9 with val_loss value: 1.833374261856079.

# %%
toytest.do_tests('CenterLoss', learner_CenterLoss, delete_models=True)
# Out:
# Testing CenterLoss for case #0
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.070669</td>
#       <td>3.016605</td>
#       <td>0.321667</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:15 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.624947</td>
#       <td>2.522679</td>
#       <td>0.576556</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.472968</td>
#       <td>2.338716</td>
#       <td>0.675889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.404700</td>
#       <td>2.484939</td>
#       <td>0.635889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.320572</td>
#       <td>2.306946</td>
#       <td>0.694444</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.250287</td>
#       <td>2.251261</td>
#       <td>0.718222</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>2.183043</td>
#       <td>2.193145</td>
#       <td>0.737222</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.108021</td>
#       <td>2.157967</td>
#       <td>0.747333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>2.065408</td>
#       <td>2.137334</td>
#       <td>0.755222</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>2.020145</td>
#       <td>2.143207</td>
#       <td>0.757889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.998339</td>
#       <td>2.135152</td>
#       <td>0.757889</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 2.5226786136627197.
# Better model found at epoch 1 with val_loss value: 2.3387160301208496.
# Better model found at epoch 3 with val_loss value: 2.30694580078125.
# Better model found at epoch 4 with val_loss value: 2.251260757446289.
# Better model found at epoch 5 with val_loss value: 2.1931445598602295.
# Better model found at epoch 6 with val_loss value: 2.1579668521881104.
# Better model found at epoch 7 with val_loss value: 2.137333869934082.
# Better model found at epoch 9 with val_loss value: 2.1351523399353027.
# Evaluation size => test:(5000, 512), train(22500, 512)
# Calculated distances in shape (5000, 22500)
#
# Testing CenterLoss for case #1
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.930404</td>
#       <td>2.829616</td>
#       <td>0.397889</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:15 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.473549</td>
#       <td>2.393100</td>
#       <td>0.631111</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.329103</td>
#       <td>2.214104</td>
#       <td>0.721889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.249981</td>
#       <td>2.198067</td>
#       <td>0.748667</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.180757</td>
#       <td>2.122674</td>
#       <td>0.785000</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.113758</td>
#       <td>2.077379</td>
#       <td>0.794667</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>2.027876</td>
#       <td>2.042873</td>
#       <td>0.803889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.964773</td>
#       <td>2.017911</td>
#       <td>0.825222</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.872011</td>
#       <td>1.974095</td>
#       <td>0.838778</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.858005</td>
#       <td>1.962394</td>
#       <td>0.841778</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.835817</td>
#       <td>1.967237</td>
#       <td>0.839111</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 2.3931002616882324.
# Better model found at epoch 1 with val_loss value: 2.214104175567627.
# Better model found at epoch 2 with val_loss value: 2.1980669498443604.
# Better model found at epoch 3 with val_loss value: 2.122673511505127.
# Better model found at epoch 4 with val_loss value: 2.0773794651031494.
# Better model found at epoch 5 with val_loss value: 2.0428733825683594.
# Better model found at epoch 6 with val_loss value: 2.017910957336426.
# Better model found at epoch 7 with val_loss value: 1.9740954637527466.
# Better model found at epoch 8 with val_loss value: 1.9623944759368896.
# Evaluation size => test:(5000, 512), train(22500, 512)
# Calculated distances in shape (5000, 22500)
#
# Testing CenterLoss for case #2
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.765034</td>
#       <td>2.669053</td>
#       <td>0.453444</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:15 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.232194</td>
#       <td>2.052594</td>
#       <td>0.715111</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.007889</td>
#       <td>1.951243</td>
#       <td>0.762111</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.938057</td>
#       <td>1.857036</td>
#       <td>0.802778</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.858348</td>
#       <td>1.767019</td>
#       <td>0.833889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.750514</td>
#       <td>1.717757</td>
#       <td>0.852111</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.701271</td>
#       <td>1.696598</td>
#       <td>0.857333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.640479</td>
#       <td>1.641956</td>
#       <td>0.876889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.551575</td>
#       <td>1.620296</td>
#       <td>0.885111</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.514248</td>
#       <td>1.626658</td>
#       <td>0.886889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.486297</td>
#       <td>1.617725</td>
#       <td>0.887889</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 2.0525941848754883.
# Better model found at epoch 1 with val_loss value: 1.9512425661087036.
# Better model found at epoch 2 with val_loss value: 1.8570364713668823.
# Better model found at epoch 3 with val_loss value: 1.7670187950134277.
# Better model found at epoch 4 with val_loss value: 1.717756986618042.
# Better model found at epoch 5 with val_loss value: 1.696597933769226.
# Better model found at epoch 6 with val_loss value: 1.641955852508545.
# Better model found at epoch 7 with val_loss value: 1.620295763015747.
# Better model found at epoch 9 with val_loss value: 1.6177252531051636.
# Evaluation size => test:(5000, 512), train(22500, 512)
# Calculated distances in shape (5000, 22500)
#
# Testing CenterLoss for case #3
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='87' class='' max='703', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       12.38% [87/703 00:01<00:11 4.4001]
#     </div>
# Better model found at epoch 7 with val_loss value: 1.942698359489441.
# Better model found at epoch 8 with val_loss value: 1.9371777772903442.
# Evaluation size => test:(5000, 512), train(22500, 512)
# Calculated distances in shape (5000, 22500)
#
# Testing CenterLoss for case #4
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.712114</td>
#       <td>2.627999</td>
#       <td>0.461889</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:15 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.320143</td>
#       <td>2.204313</td>
#       <td>0.695000</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.155493</td>
#       <td>2.081771</td>
#       <td>0.762111</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.097394</td>
#       <td>2.064007</td>
#       <td>0.781889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.029685</td>
#       <td>1.995928</td>
#       <td>0.812778</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.985888</td>
#       <td>1.946365</td>
#       <td>0.834444</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.935097</td>
#       <td>1.923614</td>
#       <td>0.850778</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.879088</td>
#       <td>1.896572</td>
#       <td>0.860444</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.814192</td>
#       <td>1.878561</td>
#       <td>0.871444</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.791525</td>
#       <td>1.868406</td>
#       <td>0.876444</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.777672</td>
#       <td>1.877408</td>
#       <td>0.871667</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 2.204312562942505.
# Better model found at epoch 1 with val_loss value: 2.0817711353302.
# Better model found at epoch 2 with val_loss value: 2.064006805419922.
# Better model found at epoch 3 with val_loss value: 1.995928406715393.
# Better model found at epoch 4 with val_loss value: 1.946365237236023.
# Better model found at epoch 5 with val_loss value: 1.9236136674880981.
# Better model found at epoch 6 with val_loss value: 1.896572232246399.
# Better model found at epoch 7 with val_loss value: 1.8785611391067505.
# Better model found at epoch 8 with val_loss value: 1.868405818939209.
# Evaluation size => test:(5000, 512), train(22500, 512)
# Calculated distances in shape (5000, 22500)
#
# Testing CenterLoss for case #5
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.783134</td>
#       <td>2.712136</td>
#       <td>0.366667</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:15 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.337517</td>
#       <td>2.188993</td>
#       <td>0.649222</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.145103</td>
#       <td>2.027579</td>
#       <td>0.754444</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.055235</td>
#       <td>1.992949</td>
#       <td>0.763222</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.976534</td>
#       <td>1.958393</td>
#       <td>0.792778</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.896139</td>
#       <td>1.867099</td>
#       <td>0.815667</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.853503</td>
#       <td>1.841426</td>
#       <td>0.821556</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.740126</td>
#       <td>1.811510</td>
#       <td>0.837222</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.673789</td>
#       <td>1.793738</td>
#       <td>0.842111</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.635540</td>
#       <td>1.785366</td>
#       <td>0.851333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.607614</td>
#       <td>1.791409</td>
#       <td>0.848222</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 2.188992977142334.
# Better model found at epoch 1 with val_loss value: 2.027578830718994.
# Better model found at epoch 2 with val_loss value: 1.9929492473602295.
# Better model found at epoch 3 with val_loss value: 1.9583932161331177.
# Better model found at epoch 4 with val_loss value: 1.867099404335022.
# Better model found at epoch 5 with val_loss value: 1.8414257764816284.
# Better model found at epoch 6 with val_loss value: 1.811510443687439.
# Better model found at epoch 7 with val_loss value: 1.793737769126892.
# Better model found at epoch 8 with val_loss value: 1.785366177558899.
# Evaluation size => test:(5000, 512), train(22500, 512)
# Calculated distances in shape (5000, 22500)
#
# Testing CenterLoss for case #6
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.076818</td>
#       <td>3.002285</td>
#       <td>0.421556</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:15 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.460305</td>
#       <td>2.345160</td>
#       <td>0.651111</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.253480</td>
#       <td>2.178702</td>
#       <td>0.727889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.148847</td>
#       <td>2.080985</td>
#       <td>0.759556</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.057890</td>
#       <td>2.009650</td>
#       <td>0.787222</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.931345</td>
#       <td>1.879560</td>
#       <td>0.820111</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.817913</td>
#       <td>1.899795</td>
#       <td>0.816333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.739162</td>
#       <td>1.818361</td>
#       <td>0.838889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.618134</td>
#       <td>1.767921</td>
#       <td>0.851333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.570714</td>
#       <td>1.757515</td>
#       <td>0.851333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.521024</td>
#       <td>1.768284</td>
#       <td>0.852333</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 2.3451600074768066.
# Better model found at epoch 1 with val_loss value: 2.1787023544311523.
# Better model found at epoch 2 with val_loss value: 2.0809850692749023.
# Better model found at epoch 3 with val_loss value: 2.009650230407715.
# Better model found at epoch 4 with val_loss value: 1.8795596361160278.
# Better model found at epoch 6 with val_loss value: 1.8183608055114746.
# Better model found at epoch 7 with val_loss value: 1.767920732498169.
# Better model found at epoch 8 with val_loss value: 1.7575151920318604.
# Evaluation size => test:(5000, 512), train(22500, 512)
# Calculated distances in shape (5000, 22500)
#
# Testing CenterLoss for case #7
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.649296</td>
#       <td>2.583869</td>
#       <td>0.420111</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:14 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.166137</td>
#       <td>2.081548</td>
#       <td>0.639889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.982180</td>
#       <td>1.917635</td>
#       <td>0.744222</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.904513</td>
#       <td>1.858001</td>
#       <td>0.750444</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.780272</td>
#       <td>1.783004</td>
#       <td>0.775111</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.761573</td>
#       <td>1.742923</td>
#       <td>0.800111</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.641717</td>
#       <td>1.663911</td>
#       <td>0.824111</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.554923</td>
#       <td>1.639961</td>
#       <td>0.841222</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.518052</td>
#       <td>1.627889</td>
#       <td>0.841333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.465418</td>
#       <td>1.625954</td>
#       <td>0.848778</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.457459</td>
#       <td>1.623489</td>
#       <td>0.848444</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 2.0815482139587402.
# Better model found at epoch 1 with val_loss value: 1.917635440826416.
# Better model found at epoch 2 with val_loss value: 1.8580008745193481.
# Better model found at epoch 3 with val_loss value: 1.7830042839050293.
# Better model found at epoch 4 with val_loss value: 1.7429227828979492.
# Better model found at epoch 5 with val_loss value: 1.6639108657836914.
# Better model found at epoch 6 with val_loss value: 1.6399613618850708.
# Better model found at epoch 7 with val_loss value: 1.6278886795043945.
# Better model found at epoch 8 with val_loss value: 1.6259537935256958.
# Better model found at epoch 9 with val_loss value: 1.6234887838363647.
# Evaluation size => test:(5000, 512), train(22500, 512)
# Calculated distances in shape (5000, 22500)
#
# Testing CenterLoss for case #8
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.132701</td>
#       <td>3.044949</td>
#       <td>0.382111</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:14 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.711315</td>
#       <td>2.608936</td>
#       <td>0.615111</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.565722</td>
#       <td>2.462768</td>
#       <td>0.731444</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.514203</td>
#       <td>2.403102</td>
#       <td>0.740556</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.415230</td>
#       <td>2.351006</td>
#       <td>0.753889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.329375</td>
#       <td>2.346689</td>
#       <td>0.778222</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>2.247408</td>
#       <td>2.276028</td>
#       <td>0.798222</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.157204</td>
#       <td>2.242011</td>
#       <td>0.818889</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>2.092632</td>
#       <td>2.231529</td>
#       <td>0.824000</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>2.057644</td>
#       <td>2.222927</td>
#       <td>0.833222</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>2.056681</td>
#       <td>2.228960</td>
#       <td>0.829889</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 2.608936309814453.
# Better model found at epoch 1 with val_loss value: 2.4627678394317627.
# Better model found at epoch 2 with val_loss value: 2.403102159500122.
# Better model found at epoch 3 with val_loss value: 2.351005792617798.
# Better model found at epoch 4 with val_loss value: 2.346689224243164.
# Better model found at epoch 5 with val_loss value: 2.2760276794433594.
# Better model found at epoch 6 with val_loss value: 2.2420105934143066.
# Better model found at epoch 7 with val_loss value: 2.2315287590026855.
# Better model found at epoch 8 with val_loss value: 2.222926616668701.
# Evaluation size => test:(5000, 512), train(22500, 512)
# Calculated distances in shape (5000, 22500)
#
# Testing CenterLoss for case #9
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.899794</td>
#       <td>2.797039</td>
#       <td>0.455889</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# Total time: 02:13 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.382316</td>
#       <td>2.259260</td>
#       <td>0.667667</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.197939</td>
#       <td>2.150046</td>
#       <td>0.721444</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.094308</td>
#       <td>2.000933</td>
#       <td>0.766111</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.008674</td>
#       <td>1.931966</td>
#       <td>0.781556</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.914232</td>
#       <td>1.887405</td>
#       <td>0.802444</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.809144</td>
#       <td>1.810254</td>
#       <td>0.833111</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.714628</td>
#       <td>1.784780</td>
#       <td>0.835333</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.643992</td>
#       <td>1.773717</td>
#       <td>0.846222</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.609240</td>
#       <td>1.761455</td>
#       <td>0.853667</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.583231</td>
#       <td>1.751187</td>
#       <td>0.855667</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with val_loss value: 2.259260416030884.
# Better model found at epoch 1 with val_loss value: 2.1500461101531982.
# Better model found at epoch 2 with val_loss value: 2.0009326934814453.
# Better model found at epoch 3 with val_loss value: 1.9319661855697632.
# Better model found at epoch 4 with val_loss value: 1.8874049186706543.
# Better model found at epoch 5 with val_loss value: 1.8102542161941528.
# Better model found at epoch 6 with val_loss value: 1.7847802639007568.
# Better model found at epoch 7 with val_loss value: 1.7737170457839966.
# Better model found at epoch 8 with val_loss value: 1.7614549398422241.
# Better model found at epoch 9 with val_loss value: 1.7511874437332153.
# Evaluation size => test:(5000, 512), train(22500, 512)
# Calculated distances in shape (5000, 22500)
# Deleting *.pth under /home/blmdr/lab/metric_learning/data_CIFAR10/images...

# %% [markdown]
# # Summary

# %%
toytest.test_summary()
toytest.save_results('results_AnomalyCIFAR10')
# Out:
# # Stat: AUC
# # Stat: Normalized distances
# ## [0]: normalized mean distance
#          Conventional  L2-constrainted   ArcFace   CosFace  ShpereFace  \
# <unk> 0      1.203465         3.160680  1.921355  1.816707    1.393288
# 1            1.024070         0.576766  0.767479  0.804392    1.002822
# 2            0.960101         1.702276  1.698105  1.603034    1.022394
# 3            0.956618         1.079263  0.941835  0.896777    1.010184
# 4            0.974828         1.542323  1.423413  1.508906    1.109236
# 5            1.109488         0.576974  0.590166  0.516355    0.922983
# 6            1.086894         0.840413  0.884766  0.904645    1.053801
# 7            0.791998         0.747893  0.715005  0.771599    0.967627
# 8            1.038950         0.843736  0.922160  0.767195    1.017341
# 9            0.926186         0.880525  0.743043  0.831256    0.896513
#
#          CenterLoss
# <unk> 0    2.846284
# 1          0.687860
# 2          1.728535
# 3          1.063133
# 4          1.399306
# 5          0.554969
# 6          0.841582
# 7          0.820860
# 8          0.735769
# 9          0.790505
# ## [1]: normalized mean distance
#          Conventional  L2-constrainted   ArcFace   CosFace  ShpereFace  \
# 0            1.049059         1.213376  1.088183  1.127195    1.142881
# <unk> 1      1.320501         1.202261  1.087826  1.051459    1.348541
# 2            1.013641         1.743085  1.822768  1.769844    0.963915
# 3            0.971460         1.126012  1.106238  1.023240    0.984865
# 4            0.974169         1.531168  1.522040  1.592715    1.122283
# 5            0.929362         0.587709  0.777506  0.641476    1.020846
# 6            0.869145         0.826284  0.916396  0.879603    1.011322
# 7            0.831340         0.831304  0.693558  0.789962    0.947881
# 8            1.050271         0.749833  0.844900  0.743165    1.041007
# 9            1.207024         0.548492  0.751051  0.741805    0.975614
#
#          CenterLoss
# 0          1.199091
# <unk> 1    1.076176
# 2          1.594229
# 3          1.101999
# 4          1.427243
# 5          0.658456
# 6          0.848498
# 7          0.944384
# 8          0.772119
# 9          0.541564
# ## [2]: normalized mean distance
#          Conventional  L2-constrainted   ArcFace   CosFace  ShpereFace  \
# 0            1.073117         1.262627  1.180999  1.188443    1.067045
# 1            0.991124         0.651047  0.730003  0.887676    1.048599
# <unk> 2      1.216080         2.495636  2.043737  1.760723    1.411195
# 3            0.971915         1.133777  0.954168  0.969167    0.986066
# 4            0.974179         1.270045  1.281220  1.197335    1.056766
# 5            0.974513         0.581022  0.623100  0.776839    1.090687
# 6            0.997258         0.818399  0.841170  0.911321    1.102254
# 7            0.878124         0.822962  0.877287  0.791491    0.916984
# 8            1.067273         0.854574  0.868393  0.821814    0.970402
# 9            0.943067         0.860396  0.965290  0.974841    1.029905
#
#          CenterLoss
# 0          1.324204
# 1          0.598098
# <unk> 2    2.338552
# 3          1.020207
# 4          1.208365
# 5          0.599201
# 6          0.956516
# 7          0.885808
# 8          0.796745
# 9          0.792687
# ## [3]: normalized mean distance
#          Conventional  L2-constrainted   ArcFace   CosFace  ShpereFace  \
# 0            0.991019         1.120213  1.095096  1.098778    1.015540
# 1            1.196269         0.626567  0.850129  0.891586    0.859546
# 2            0.956644         1.766951  1.613632  1.667338    0.830723
# <unk> 3      1.163952         2.919322  1.940091  2.008584    1.022285
# 4            0.883502         1.430025  1.458768  1.386014    0.927367
# 5            1.002342         0.593103  0.655452  0.772804    1.026308
# 6            0.954131         0.800097  0.853466  0.833736    1.141629
# 7            0.912163         0.902845  0.787118  0.776059    0.924297
# 8            1.027492         0.727533  0.943258  0.839336    1.082952
# 9            0.870049         0.835505  0.979161  0.836722    0.893578
#
#          CenterLoss
# 0          1.147506
# 1          0.544051
# 2          1.503242
# <unk> 3    2.552199
# 4          1.445118
# 5          0.452291
# 6          0.653246
# 7          0.773224
# 8          0.829595
# 9          0.690779
# ## [4]: normalized mean distance
#          Conventional  L2-constrainted   ArcFace   CosFace  ShpereFace  \
# 0            1.037302         1.233823  1.216478  1.148644    1.177563
# 1            1.200521         0.655858  0.675829  0.803512    1.046705
# 2            0.986328         1.516457  1.401825  1.242107    0.949408
# 3            0.926011         1.038586  0.996754  1.067662    1.047707
# <unk> 4      1.088282         1.937181  1.785025  1.509383    0.986910
# 5            1.002337         0.600589  0.604903  0.608822    1.154312
# 6            1.067627         0.771711  0.893675  0.825813    1.090447
# 7            0.914634         0.877494  0.810984  0.821209    0.999913
# 8            1.050477         0.767160  0.912407  0.858601    1.133699
# 9            0.990654         0.803839  0.820823  0.876822    0.873750
#
#          CenterLoss
# 0          1.117345
# 1          0.537286
# 2          1.405765
# 3          0.923466
# <unk> 4    1.888535
# 5          0.610334
# 6          0.738707
# 7          0.829723
# 8          0.683769
# 9          0.835528
# ## [5]: normalized mean distance
#          Conventional  L2-constrainted   ArcFace   CosFace  ShpereFace  \
# 0            0.935847         1.108204  1.164829  1.027578    1.014960
# 1            1.245533         0.654984  0.661672  0.686122    0.861997
# 2            0.951470         1.647586  1.694592  1.567911    0.987456
# 3            0.928594         0.926241  1.054047  1.024759    0.928044
# 4            1.002325         1.459254  1.433696  1.501901    1.025653
# <unk> 5      1.041493         2.493072  2.051218  1.901358    1.126400
# 6            0.998120         0.807261  0.867449  0.902411    1.135127
# 7            0.802087         0.962668  0.743174  0.784188    0.903297
# 8            1.076786         0.751828  0.841040  0.737553    1.049812
# 9            0.962602         0.777520  0.685437  0.836882    0.957844
#
#          CenterLoss
# 0          1.152151
# 1          0.727448
# 2          1.668109
# 3          1.102717
# 4          1.667749
# <unk> 5    2.638370
# 6          0.825132
# 7          1.015824
# 8          0.702442
# 9          0.804044
# ## [6]: normalized mean distance
#          Conventional  L2-constrainted   ArcFace   CosFace  ShpereFace  \
# 0            1.084544         1.231348  1.138744  1.124340    1.098091
# 1            1.326077         0.596427  0.774364  1.001893    0.858862
# 2            1.004338         1.974361  1.615555  1.728678    0.985180
# 3            0.986631         1.110001  0.990350  0.962924    0.964073
# 4            1.052998         1.396655  1.555601  1.402707    1.091647
# 5            0.948258         0.630239  0.684851  0.831643    1.115721
# <unk> 6      1.268532         2.640962  1.892236  1.839415    1.321479
# 7            0.901215         0.919967  0.699374  0.764228    0.998583
# 8            1.048235         0.853273  0.757735  0.739411    1.028631
# 9            0.926682         0.847434  0.804719  0.884135    0.883422
#
#          CenterLoss
# 0          1.395568
# 1          0.761465
# 2          2.069434
# 3          1.215964
# 4          1.447128
# 5          0.703222
# <unk> 6    2.726082
# 7          1.073020
# 8          0.724563
# 9          0.867540
# ## [7]: normalized mean distance
#          Conventional  L2-constrainted   ArcFace   CosFace  ShpereFace  \
# 0            0.930573         1.227959  1.182868  0.980753    1.098415
# 1            1.069358         0.628881  0.632129  0.765549    0.998261
# 2            0.958462         1.826146  1.621637  1.642754    1.008807
# 3            0.901913         1.176485  1.071874  1.099298    0.990810
# 4            0.933442         1.611507  1.541774  1.447648    0.970086
# 5            0.895151         0.605007  0.692826  0.679080    0.893086
# 6            1.056249         0.835701  0.925380  0.881399    1.074821
# <unk> 7      1.261394         2.849946  1.692366  1.672972    1.352500
# 8            1.033694         0.658265  0.634835  0.597649    0.942782
# 9            1.023909         0.810821  0.794341  0.898815    0.859175
#
#          CenterLoss
# 0          1.158718
# 1          0.627799
# 2          1.838834
# 3          1.119262
# 4          1.604104
# 5          0.550365
# 6          0.778624
# <unk> 7    2.574707
# 8          0.622025
# 9          0.766429
# ## [8]: normalized mean distance
#          Conventional  L2-constrainted   ArcFace   CosFace  ShpereFace  \
# 0            1.008741         1.251683  1.196335  1.084221    1.089901
# 1            1.470366         0.584161  0.913079  0.690990    0.936699
# 2            0.882852         1.778918  1.682915  1.577746    1.019476
# 3            0.984685         1.104918  1.112897  1.122985    1.012046
# 4            0.992132         1.562599  1.467853  1.522352    1.051871
# 5            1.052201         0.615179  0.584992  0.572406    0.970450
# 6            1.026116         0.861923  0.886089  0.894593    1.067858
# 7            0.841957         0.759782  0.731135  0.782967    0.933098
# <unk> 8      1.089799         2.204102  1.401670  1.413933    1.395719
# 9            0.914630         0.854712  0.771941  1.021676    0.969344
#
#          CenterLoss
# 0          1.454243
# 1          0.643526
# 2          1.942425
# 3          1.071922
# 4          1.653679
# 5          0.549599
# 6          0.948639
# 7          0.924199
# <unk> 8    2.281215
# 9          0.753180
# ## [9]: normalized mean distance
#          Conventional  L2-constrainted   ArcFace   CosFace  ShpereFace  \
# 0            1.066589         1.263532  1.101342  1.200653    1.109972
# 1            1.579376         0.470169  0.804855  1.044618    0.856590
# 2            0.984806         1.808416  1.729576  1.671702    0.814318
# 3            0.903831         1.129164  1.014104  1.031007    0.882604
# 4            1.006710         1.510882  1.545584  1.382578    0.942972
# 5            0.869976         0.669544  0.660329  0.600378    1.040537
# 6            0.958912         0.836374  0.838057  0.901827    1.022921
# 7            0.902116         0.805206  0.755715  0.759173    0.854524
# 8            0.964236         0.826180  0.838310  0.848259    1.042509
# <unk> 9      1.482662         1.534245  1.218056  1.351587    1.381171
#
#          CenterLoss
# 0          1.217107
# 1          0.434101
# 2          1.727798
# 3          1.217995
# 4          1.617925
# 5          0.650400
# 6          0.925382
# 7          0.902196
# 8          0.763103
# <unk> 9    1.472074

# %%
for i in [0, 5]: toytest.show_all_worst_test_images(i)
